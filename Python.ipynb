# %%
import pandas as pd
import numpy as np

# %%
airports = pd.read_csv('dataSet/airports.csv')
airport_freq = pd.read_csv('dataSet/airport-frequencies.csv')
runways = pd.read_csv('dataSet/runways.csv')
countries = pd.read_csv('dataSet/countries.csv')
regions = pd.read_csv('dataSet/regions.csv')
navaids = pd.read_csv('dataSet/navaids.csv')
movie = pd.read_csv('dataSet/movie.csv')
hell = pd.read_csv('dataSet/column_hell.csv')
df = pd.read_csv('dataSet/howpop_train.csv')

# %%
airports
# Out:
#            id    ident            type                                name  \
# 0        6523      00A        heliport                   Total Rf Heliport
# 1      323361     00AA   small_airport                Aero B Ranch Airport
# 2        6524     00AK   small_airport                        Lowell Field
# 3        6525     00AL   small_airport                        Epps Airpark
# 4        6526     00AR          closed  Newport Hospital & Clinic Heliport
# ...       ...      ...             ...                                 ...
# 64148   32753     ZYYY  medium_airport             Shenyang Dongta Airport
# 64149   46378  ZZ-0001        heliport                     Sealand Helipad
# 64150  307326  ZZ-0002   small_airport           Glorioso Islands Airstrip
# 64151  342102     ZZZW          closed              Scandium City Heliport
# 64152  313629     ZZZZ   small_airport              Satsuma Iōjima Airport
#
# ...

# %%
airports.tail()
# Out:
#            id    ident            type                       name  \
# 64148   32753     ZYYY  medium_airport    Shenyang Dongta Airport
# 64149   46378  ZZ-0001        heliport            Sealand Helipad
# 64150  307326  ZZ-0002   small_airport  Glorioso Islands Airstrip
# 64151  342102     ZZZW          closed     Scandium City Heliport
# 64152  313629     ZZZZ   small_airport     Satsuma Iōjima Airport
#
#        latitude_deg  longitude_deg  elevation_ft continent iso_country  \
# 64148     41.784401     123.496002           NaN        AS          CN
# 64149     51.894444       1.482500          40.0        EU          GB
# 64150    -11.584278      47.296389          11.0        AF          TF
# 64151     69.355287    -138.939310           4.0       NaN          CA
# 64152     30.784722     130.270556         338.0        AS          JP
#
#       iso_region         municipality scheduled_service gps_code iata_code  \
# ...

# %%
airports.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64153 entries, 0 to 64152
# Data columns (total 18 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 64153 non-null  int64
#  1   ident              64152 non-null  object
#  2   type               64153 non-null  object
#  3   name               64153 non-null  object
#  4   latitude_deg       64153 non-null  float64
#  5   longitude_deg      64153 non-null  float64
#  6   elevation_ft       52166 non-null  float64
#  7   continent          32838 non-null  object
#  8   iso_country        63904 non-null  object
#  9   iso_region         64153 non-null  object
#  10  municipality       58737 non-null  object
#  11  scheduled_service  64153 non-null  object
#  12  gps_code           42226 non-null  object
#  13  iata_code          9264 non-null   object
#  14  local_code         31482 non-null  object
#  15  home_link          3260 non-null   object
# ...

# %%
airports.describe()
# Out:
#                   id  latitude_deg  longitude_deg  elevation_ft
# count   64153.000000  64153.000000   64153.000000  52166.000000
# mean   119764.215828     25.728509     -31.794058   1265.040946
# std    142652.832788     26.711810      83.209752   1622.301789
# min         2.000000    -90.000000    -179.876999  -1266.000000
# 25%     16172.000000      9.811460     -93.251801    209.000000
# 50%     32501.000000     35.535599     -70.652222    726.000000
# 75%    318603.000000     43.224800      17.986111   1550.000000
# max    343464.000000     82.750000     179.975700  22000.000000

# %%
airports.name
# Out:
# 0                         Total Rf Heliport
# 1                      Aero B Ranch Airport
# 2                              Lowell Field
# 3                              Epps Airpark
# 4        Newport Hospital & Clinic Heliport
#                         ...
# 64148               Shenyang Dongta Airport
# 64149                       Sealand Helipad
# 64150             Glorioso Islands Airstrip
# 64151                Scandium City Heliport
# 64152                Satsuma Iōjima Airport
# Name: name, Length: 64153, dtype: object

# %%
airports[['name','iso_country', 'iso_region', 'municipality']]
# Out:
#                                      name iso_country iso_region  \
# 0                       Total Rf Heliport          US      US-PA
# 1                    Aero B Ranch Airport          US      US-KS
# 2                            Lowell Field          US      US-AK
# 3                            Epps Airpark          US      US-AL
# 4      Newport Hospital & Clinic Heliport          US      US-AR
# ...                                   ...         ...        ...
# 64148             Shenyang Dongta Airport          CN      CN-21
# 64149                     Sealand Helipad          GB     GB-ENG
# 64150           Glorioso Islands Airstrip          TF     TF-U-A
# 64151              Scandium City Heliport          CA      CA-YT
# 64152              Satsuma Iōjima Airport          JP      JP-46
#
#               municipality
# 0                 Bensalem
# 1                    Leoti
# 2             Anchor Point
# 3                  Harvest
# 4                  Newport
# ...

# %%
airports.loc[100:105, 'name':'iso_country']
# Out:
#                                name  latitude_deg  longitude_deg  \
# 100                  Detour Airport     40.843601    -100.653000
# 101                  Moore Airfield     43.644500     -72.086998
# 102  Albert Guido Memorial Heliport     40.741798     -74.137100
# 103          Champion Ranch Airport     33.008611    -104.540278
# 104           Lantana Ranch Airport     38.763901    -119.027000
# 105        Vassar Hospital Heliport     41.692415     -73.936830
#
#      elevation_ft continent iso_country
# 100        3000.0       NaN          US
# 101         835.0       NaN          US
# 102          10.0       NaN          US
# 103        3630.0       NaN          US
# 104        4600.0       NaN          US
# 105         100.0       NaN          US

# %%
airports.iloc[100:105, 0:8]
# Out:
#         id ident           type                            name  latitude_deg  \
# 100   6612  01NE  small_airport                  Detour Airport     40.843601
# 101   6613  01NH  small_airport                  Moore Airfield     43.644500
# 102   6614  01NJ       heliport  Albert Guido Memorial Heliport     40.741798
# 103  45537  01NM  small_airport          Champion Ranch Airport     33.008611
# 104   6615  01NV  small_airport           Lantana Ranch Airport     38.763901
#
#      longitude_deg  elevation_ft continent
# 100    -100.653000        3000.0       NaN
# 101     -72.086998         835.0       NaN
# 102     -74.137100          10.0       NaN
# 103    -104.540278        3630.0       NaN
# 104    -119.027000        4600.0       NaN

# %%
airports[(airports['iso_country'] == 'US') & (airports['municipality'] == 'New York')]
# Out:
#            id ident           type  \
# 7511    13405   6N5       heliport
# 7512    13406   6N6  seaplane_base
# 7513    13407   6N7  seaplane_base
# 29476  313333   JPB         closed
# 29478   18256   JRA       heliport
# 29479   18257   JRB       heliport
# 31497    3521  KEWR  large_airport
# 32097    3622  KJFK  large_airport
# 32236    3643  KLGA  large_airport
# 32666   35135  KNOP         closed
# 41418   23173  NK39       heliport
# 41983   23404  NY22       heliport
#
#                                                     name  latitude_deg  \
# 7511                           East 34th Street Heliport     40.742599
# 7512                                 Evers Seaplane Base     40.845901
# 7513                 New York Skyports Inc Seaplane Base     40.735061
# 29476                           Pan Am Building Heliport     40.753300
# 29478                             West 30th St. Heliport     40.754501
# 29479                Downtown-Manhattan/Wall St Heliport     40.701199
# ...

# %%
airports[(airports['iso_country'] == 'TJ') & (airports['municipality'] == 'Dushanbe')]
# Out:
#           id    ident            type              name  latitude_deg  \
# 53825   6375  TJ-UT45  medium_airport   Gissar Air Base     38.512299
# 59226  26385     UTDD  medium_airport  Dushanbe Airport     38.543301
#
#        longitude_deg  elevation_ft continent iso_country iso_region  \
# 53825      68.672501        2379.0        AS          TJ      TJ-RR
# 59226      68.824997        2575.0        AS          TJ      TJ-RR
#
#       municipality scheduled_service gps_code iata_code local_code home_link  \
# 53825     Dushanbe                no      NaN       NaN        NaN       NaN
# 59226     Dushanbe               yes     UTDD       DYU        NaN       NaN
#
#                                        wikipedia_link  \
# 53825   https://en.wikipedia.org/wiki/Gissar_Air_Base
# 59226  https://en.wikipedia.org/wiki/Dushanbe_Airport
#
#                         keywords
# 53825  UT45, Душанбе, Stalinabad
# 59226                        NaN

# %%
airports[(airports['iso_country'] == 'TJ') & (airports['municipality'] == 'Khujand')]
# Out:
#           id ident            type             name  latitude_deg  \
# 59228  26386  UTDL  medium_airport  Khujand Airport     40.215401
#
#        longitude_deg  elevation_ft continent iso_country iso_region  \
# 59228      69.694702        1450.0        AS          TJ      TJ-SU
#
#       municipality scheduled_service gps_code iata_code local_code home_link  \
# 59228      Khujand               yes     UTDL       LBD        NaN       NaN
#
#                                         wikipedia_link  \
# 59228  https://en.wikipedia.org/wiki/Khudzhand_Airport
#
#                                         keywords
# 59228  Khodjend, Khodzhent, Leninabad, Khudzhand

# %%
TJ = airports[(airports['iso_country'] == 'TJ') & (airports['elevation_ft'] > 2500)]
TJ
# Out:
#            id    ident            type               name  latitude_deg  \
# 53818  300330  TJ-0003   small_airport       Ayni Airport     39.405556
# 53819  300331  TJ-0004   small_airport  Penjikent Airport     39.482222
# 53820  300332  TJ-0005   small_airport       Garm Airport     39.003889
# 53824    6374  TJ-UT44   small_airport    Murghab Airport     38.190399
# 59138    6371     UT1A   small_airport     Isfara Airport     40.120602
# 59140    6373     UT1C   small_airport     Khorog Airport     37.502222
# 59226   26385     UTDD  medium_airport   Dushanbe Airport     38.543301
#
#        longitude_deg  elevation_ft continent iso_country iso_region  \
# 53818      68.522778        4655.0        AS          TJ      TJ-SU
# 53819      67.605556        3400.0        AS          TJ      TJ-SU
# 53820      70.290278        4280.0        AS          TJ      TJ-RR
# 53824      74.024696       11962.0        AS          TJ      TJ-GB
# ...

# %%
# Добавление в csv file
try:
    TJ.to_csv("dataSet/TajAirports.csv", sep = '\t', encoding = 'utf-8')
except Exception as e:
    print(f"Error: {e}")

# %%
airports[(airports['iso_region'] == 'US-CA') & (airports.type == 'large_airport')][['ident', 'name', 'municipality']]
# Out:
#       ident                                             name   municipality
# 30571  KBAB                             Beale Air Force Base     Marysville
# 31415  KEDW                           Edwards Air Force Base        Edwards
# 31561  KFAT            Fresno Yosemite International Airport         Fresno
# 32212  KLAX                Los Angeles International Airport    Los Angeles
# 32741  KOAK       Metropolitan Oakland International Airport        Oakland
# 32797  KONT                    Ontario International Airport        Ontario
# 34322  KSAN                  San Diego International Airport      San Diego
# 34362  KSFO              San Francisco International Airport  San Francisco
# 34383  KSJC  Norman Y. Mineta San Jose International Airport       San Jose
# 34405  KSMF                 Sacramento International Airport     Sacramento
# 34411  KSNA         John Wayne Airport-Orange County Airport      Santa Ana
# ...

# %%
airport_freq[airport_freq.airport_ident == 'KLAX'].sort_values('frequency_mhz', ascending=False)
# Out:
#           id  airport_ref airport_ident  type description  frequency_mhz
# 11965  60773         3632          KLAX  MISC          CG         898.40
# 11960  60768         3632          KLAX  ATIS        ATIS         133.80
# 11959  60766         3632          KLAX   APP   SOCAL APP         124.30
# 11962  60770         3632          KLAX   DEP   SOCAL DEP         124.30
# 11968  60776         3632          KLAX  UNIC      UNICOM         122.95
# 11963  60771         3632          KLAX   GND         GND         121.65
# 11961  60769         3632          KLAX   CLD    CLNC DEL         121.40
# 11967  60775         3632          KLAX   TWR         TWR         119.80
# 11966  60774         3632          KLAX   OPS          AF          37.22
# 11958  60767         3632          KLAX   APP   SOCAL APP          36.07
# 11964  60772         3632          KLAX  MISC          CG          34.50

# %%
# sort by asc
airport_freq[airport_freq.airport_ident == 'KLAX'].sort_values('type')
# Out:
#           id  airport_ref airport_ident  type description  frequency_mhz
# 11958  60767         3632          KLAX   APP   SOCAL APP          36.07
# 11959  60766         3632          KLAX   APP   SOCAL APP         124.30
# 11960  60768         3632          KLAX  ATIS        ATIS         133.80
# 11961  60769         3632          KLAX   CLD    CLNC DEL         121.40
# 11962  60770         3632          KLAX   DEP   SOCAL DEP         124.30
# 11963  60771         3632          KLAX   GND         GND         121.65
# 11964  60772         3632          KLAX  MISC          CG          34.50
# 11965  60773         3632          KLAX  MISC          CG         898.40
# 11966  60774         3632          KLAX   OPS          AF          37.22
# 11967  60775         3632          KLAX   TWR         TWR         119.80
# 11968  60776         3632          KLAX  UNIC      UNICOM         122.95

# %%
# SQL analog IN
airports[airports.type.isin(['heliport', ['baloonport']])]
# Out:
#            id    ident      type                             name  \
# 0        6523      00A  heliport                Total Rf Heliport
# 9      322658     00CN  heliport  Kitchen Creek Helibase Heliport
# 12       6532     00FD  heliport               Ringhaver Heliport
# 15       6535     00GE  heliport                 Caffrey Heliport
# 16       6536     00HI  heliport               Kaupulehu Heliport
# ...       ...      ...       ...                              ...
# 63790  342045  ZA-0214  heliport    Mediclinic Midstream Heliport
# 63791  342046  ZA-0215  heliport                  Benoni Heliport
# 63854  339169     ZGNT  heliport         Shenzhen Nantou Heliport
# 63877  301278      ZIZ  heliport                 Zamzama Heliport
# 64149   46378  ZZ-0001  heliport                  Sealand Helipad
#
#        latitude_deg  longitude_deg  elevation_ft continent iso_country  \
# 0         40.070801     -74.933601          11.0       NaN          US
# ...

# %%
airports.groupby(['iso_country', 'type']).size()
# Out:
# iso_country  type
# AD           closed              1
#              heliport            2
# AE           closed              2
#              heliport           78
#              large_airport       4
#                               ...
# ZW           closed              2
#              large_airport       1
#              medium_airport      8
#              small_airport     131
# ZZ           heliport            1
# Length: 913, dtype: int64

# %%
airport_freq[airport_freq.airport_ident == 'KLAX'].sort_values('type')
# Out:
#           id  airport_ref airport_ident  type description  frequency_mhz
# 11958  60767         3632          KLAX   APP   SOCAL APP          36.07
# 11959  60766         3632          KLAX   APP   SOCAL APP         124.30
# 11960  60768         3632          KLAX  ATIS        ATIS         133.80
# 11961  60769         3632          KLAX   CLD    CLNC DEL         121.40
# 11962  60770         3632          KLAX   DEP   SOCAL DEP         124.30
# 11963  60771         3632          KLAX   GND         GND         121.65
# 11964  60772         3632          KLAX  MISC          CG          34.50
# 11965  60773         3632          KLAX  MISC          CG         898.40
# 11966  60774         3632          KLAX   OPS          AF          37.22
# 11967  60775         3632          KLAX   TWR         TWR         119.80
# 11968  60776         3632          KLAX  UNIC      UNICOM         122.95

# %%
airports[airports.iso_country.isin(['TJ','US']).groupby(['iso_country','type']).size().sort('type')
# Out:
#   File "<ipython-input-47-90fc81aef9a0>", line 1
#     airports[airports.iso_country.isin(['TJ','US']).groupby(['iso_country','type']).size().sort('type')
#                                                                                                        ^
# SyntaxError: unexpected EOF while parsing

# %%
runways
# Out:
#            id  airport_ref airport_ident  length_ft  width_ft   surface  \
# 0      269408         6523           00A       80.0      80.0    ASPH-G
# 1      255155         6524          00AK     2500.0      70.0      GRVL
# 2      254165         6525          00AL     2300.0     200.0      TURF
# 3      270932         6526          00AR       40.0      40.0     GRASS
# 4      322128       322127          00AS     1450.0      60.0      Turf
# ...       ...          ...           ...        ...       ...       ...
# 41976  327703       327451          ZYSQ     8202.0     148.0       NaN
# 41977  235188        27242          ZYTL    10827.0     148.0       CON
# 41978  235186        27243          ZYTX    10499.0     148.0   Asphalt
# 41979  235169        27244          ZYYJ     8530.0     148.0       CON
# 41980  313663       313629          ZZZZ     1713.0      82.0  concrete
#
#        lighted  closed le_ident  le_latitude_deg  le_longitude_deg  \
# ...

# %%
runways[runways.airport_ident == 'KLAX'].sort_values('id')
# Out:
#            id  airport_ref airport_ident  length_ft  width_ft surface  \
# 22021  240919         3632          KLAX    10285.0     150.0     CON
# 22020  240920         3632          KLAX     8925.0     150.0     CON
# 22023  240921         3632          KLAX    11096.0     200.0     CON
# 22022  240922         3632          KLAX    12091.0     150.0     CON
# 22024  321622         3632          KLAX        NaN       NaN     NaN
#
#        lighted  closed le_ident  le_latitude_deg  le_longitude_deg  \
# 22021        1       0      06R          33.9467          -118.435
# 22020        1       0      06L          33.9491          -118.431
# 22023        1       0      07R          33.9338          -118.419
# 22022        1       0      07L          33.9358          -118.419
# 22024        0       1      09l              NaN               NaN
#
#        le_elevation_ft  le_heading_degT  le_displaced_threshold_ft he_ident  \
# ...

# %%
runways.groupby(['airport_ref', 'airport_ident']).size()
# Out:
# airport_ref  airport_ident
# 2            OM11             1
# 3            AGGH             1
# 4            AGGM             1
# 5            AL-LA10          1
# 7            UD21             2
#                              ..
# 343454       8WY6             1
# 343456       98WT             1
# 343458       US-3785          1
# 343460       US-3786          1
# 343462       US-3787          1
# Length: 35430, dtype: int64

# %%
runways[(runways['surface'] == 'GRASS')]
# Out:
#            id  airport_ref airport_ident  length_ft  width_ft surface  \
# 3      270932         6526          00AR       40.0      40.0   GRASS
# 1260   264502        45941          10WY     4500.0     100.0   GRASS
# 8743   270707        14536          81MO       60.0      60.0   GRASS
# 12226  253826          745          CCA9     1800.0     150.0   GRASS
# 13274  251535         1498          CSA2     1800.0      50.0   GRASS
# ...       ...          ...           ...        ...       ...     ...
# 35389  270983        30381          SSNJ     3615.0     164.0   GRASS
# 35404  264401        45593          SSNY     3937.0      66.0   GRASS
# 35413  264393        45583          SSOJ     2953.0      98.0   GRASS
# 35593  264397        45631          SSWH     2625.0      98.0   GRASS
# 35595  270937        46358          SSWJ       66.0      66.0   GRASS
#
#        lighted  closed le_ident  le_latitude_deg  le_longitude_deg  \
# ...

# %%
airports[airports.iso_country == 'US'].groupby('type').filter(lambda g: len(g) > 1000).groupby('type').size().sort_values(ascending=False)
# Out:
# type
# small_airport    13846
# heliport          6820
# closed            3499
# dtype: int64

# %%
runways.agg({'length_ft': ['min', 'max', 'mean', 'median', 'sum']}).T
# Out:
#            min       max         mean  median          sum
# length_ft  0.0  120000.0  3263.414576  2738.0  136345461.0

# %%
airport_freq.merge(airports[airports.ident == 'KLAX'][['id']],
                  left_on='airport_ref', right_on = 'id',
                  how='left')[['airport_ident', 'type', 'description', 'frequency_mhz']]
# Out:
#       airport_ident   type               description  frequency_mhz
# 0              00CA   CTAF                      CTAF        122.900
# 1              01FL  ARCAL                       NaN        122.900
# 2              01FL   CTAF       CEDAR KNOLL TRAFFIC        122.800
# 3              04CA   CTAF                      CTAF        122.900
# 4              04MS   UNIC                    UNICOM        122.800
# ...             ...    ...                       ...            ...
# 28934          ZYTL    TWR                DALIAN TWR        118.250
# 28935          ZYTX   APPR  taoxian approach low fan        119.825
# 28936          ZYTX   ATIS                      ATIS        127.450
# 28937          ZYTX    TWR              SHENYANG TWR        118.100
# 28938          ZYYJ    TWR                       TWR        130.000
#
# [28939 rows x 4 columns]

# %%
df = pd.concat([airports[airports.ident == 'KLAX'][['name', 'municipality']],
              airports[airports.ident == 'KLGB'][['name', 'municipality']]])
df
# Out:
#                                        name municipality
# 32212     Los Angeles International Airport  Los Angeles
# 32237  Long Beach Airport (Daugherty Field)   Long Beach

# %%
try:
    df = pd.concat([airports[airports.ident == 'KLAX'][['name', 'type']], 
           airports[airports.ident == 'KLGB'][['name', 'type']]])
except Exception as e:
    print(f"Error: {e}")
df
# Out:
#                                        name            type
# 32212     Los Angeles International Airport   large_airport
# 32237  Long Beach Airport (Daugherty Field)  medium_airport

# %%
runways.to_excel('runways.xls')

# %%
runways2 = pd.read_excel('runways.xls')
runways2
# Out:
#        Unnamed: 0      id  airport_ref airport_ident  length_ft  width_ft  \
# 0               0  269408         6523           00A       80.0      80.0
# 1               1  255155         6524          00AK     2500.0      70.0
# 2               2  254165         6525          00AL     2300.0     200.0
# 3               3  270932         6526          00AR       40.0      40.0
# 4               4  322128       322127          00AS     1450.0      60.0
# ...           ...     ...          ...           ...        ...       ...
# 41976       41976  327703       327451          ZYSQ     8202.0     148.0
# 41977       41977  235188        27242          ZYTL    10827.0     148.0
# 41978       41978  235186        27243          ZYTX    10499.0     148.0
# 41979       41979  235169        27244          ZYYJ     8530.0     148.0
# 41980       41980  313663       313629          ZZZZ     1713.0      82.0
#
#         surface  lighted  closed le_ident  ...  le_longitude_deg  \
# ...

# %%
runways2 = pd.read_excel('runways.xls', index_col=0)
runways2
# Out:
#            id  airport_ref airport_ident  length_ft  width_ft   surface  \
# 0      269408         6523           00A       80.0      80.0    ASPH-G
# 1      255155         6524          00AK     2500.0      70.0      GRVL
# 2      254165         6525          00AL     2300.0     200.0      TURF
# 3      270932         6526          00AR       40.0      40.0     GRASS
# 4      322128       322127          00AS     1450.0      60.0      Turf
# ...       ...          ...           ...        ...       ...       ...
# 41976  327703       327451          ZYSQ     8202.0     148.0       NaN
# 41977  235188        27242          ZYTL    10827.0     148.0       CON
# 41978  235186        27243          ZYTX    10499.0     148.0   Asphalt
# 41979  235169        27244          ZYYJ     8530.0     148.0       CON
# 41980  313663       313629          ZZZZ     1713.0      82.0  concrete
#
#        lighted  closed le_ident  le_latitude_deg  le_longitude_deg  \
# ...

# %%
xl_writer = pd.ExcelWriter('runways.xls')
runways.to_excel(xl_writer, sheet_name='All')
runways2[runways2.length_ft > 1500].to_excel(xl_writer, sheet_name='gt_2000')
xl_writer.save()

# %%
movie
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 4       NaN        Doug Walker                     NaN       NaN
# ...     ...                ...                     ...       ...
# 4911  Color        Scott Smith                     1.0      87.0
# 4912  Color                NaN                    43.0      43.0
# 4913  Color   Benjamin Roberds                    13.0      76.0
# 4914  Color        Daniel Hsia                    14.0     100.0
# 4915  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                         0.0                   855.0  Joel David Moore
# ...

# %%
movie = pd.read_csv('dataSet/movie.csv')
movie_actor_director = movie[['actor_1_name', 'actor_2_name',
    'actor_3_name', 'director_name', 'movie_title']]
movie_actor_director
# Out:
#          actor_1_name      actor_2_name          actor_3_name  \
# 0         CCH Pounder  Joel David Moore             Wes Studi
# 1         Johnny Depp     Orlando Bloom        Jack Davenport
# 2     Christoph Waltz      Rory Kinnear      Stephanie Sigman
# 3           Tom Hardy    Christian Bale  Joseph Gordon-Levitt
# 4         Doug Walker        Rob Walker                   NaN
# ...               ...               ...                   ...
# 4911      Eric Mabius     Daphne Zuniga          Crystal Lowe
# 4912      Natalie Zea     Valorie Curry         Sam Underwood
# 4913      Eva Boehnke     Maxwell Moody        David Chandler
# 4914        Alan Ruck     Daniel Henney           Eliza Coupe
# 4915      John August  Brian Herzlinger              Jon Gunn
#
#           director_name                                 movie_title
# 0         James Cameron                                      Avatar
# 1        Gore Verbinski    Pirates of the Caribbean: At World's End
# ...

# %%
JC_movie = movie[movie.director_name == 'James Cameron']
JC_movie
# Out:
#       color  director_name  num_critic_for_reviews  duration  \
# 0     Color  James Cameron                   723.0     178.0
# 26    Color  James Cameron                   315.0     194.0
# 285   Color  James Cameron                   210.0     153.0
# 288   Color  James Cameron                    94.0     141.0
# 599   Color  James Cameron                    82.0     171.0
# 2455  Color  James Cameron                   250.0     154.0
# 3508  Color  James Cameron                   204.0     107.0
#
#       director_facebook_likes  actor_3_facebook_likes       actor_2_name  \
# 0                         0.0                   855.0   Joel David Moore
# 26                        0.0                   794.0       Kate Winslet
# 285                       0.0                   539.0  Jenette Goldstein
# 288                       0.0                   618.0        Tia Carrere
# 599                       0.0                   638.0         Todd Graff
# ...

# %%
movie[(movie['director_facebook_likes'] > 2500)]
movie
# Out:
#       color  director_name  num_critic_for_reviews  duration  \
# 0     Color  James Cameron                   723.0     178.0
# 26    Color  James Cameron                   315.0     194.0
# 285   Color  James Cameron                   210.0     153.0
# 288   Color  James Cameron                    94.0     141.0
# 599   Color  James Cameron                    82.0     171.0
# 2455  Color  James Cameron                   250.0     154.0
# 3508  Color  James Cameron                   204.0     107.0
#
#       director_facebook_likes  actor_3_facebook_likes       actor_2_name  \
# 0                         0.0                   855.0   Joel David Moore
# 26                        0.0                   794.0       Kate Winslet
# 285                       0.0                   539.0  Jenette Goldstein
# 288                       0.0                   618.0        Tia Carrere
# 599                       0.0                   638.0         Todd Graff
# ...

# %%
Top = movie[['director_name', 'director_facebook_likes']].sort_values('director_name', ascending=False).head(10)
Top
# Out:
#            director_name  director_facebook_likes
# 4731       Étienne Faure                     77.0
# 4103        Éric Tessier                      0.0
# 3609    Émile Gaudreault                      9.0
# 3185  Álex de la Iglesia                    275.0
# 4769       Zoran Lisinac                      0.0
# 3502      Zal Batmanglij                    129.0
# 4821      Zal Batmanglij                    129.0
# 4354            Zak Penn                     87.0
# 4126       Zackary Adler                      0.0
# 2431           Zack Ward                    662.0

# %%
runways.to_excel('runways.xls')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-a966126bbf7e> in <module>
# ----> 1 UK_movies.to_excel('UK_movies.xls')
#
# NameError: name 'UK_movies' is not defined

# %%
UK_movie = pd.read_excel('runways.xls')
UK_movie
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-6f462a39dc9e> in <module>
# ----> 1 UK_movie = pd.read_excel('runways.xls')
#       2 UK_movie
#
# NameError: name 'pd' is not defined

# %%
movie_list =  movie[movie.country=='UK'][['movie_title', 'director_name','actor_1_name', 'actor_2_name',
    'actor_3_name']]
movie_list.to_excel('movie_list.xls')

# %%
movie.to_excel('movie.xls')
xl_writer = pd.ExcelWriter('movie.xls')
movie.to_excel(xl_writer, sheet_name='All')
movie[movie.country == 'UK'][['movie_title', 'director_name', 'actor_1_name', 'actor_2_name', 'actor_3_name']].to_excel(xl_writer, sheet_name = 'UK Films')
xl_writer.save()

# %%
Top = movie[['director_name', 'director_facebook_likes']].sort_values('director_facebook_likes', ascending=False).head(10)
Top
# Out:
#              director_name  director_facebook_likes
# 3603  Joseph Gordon-Levitt                  23000.0
# 120      Christopher Nolan                  22000.0
# 1057     Christopher Nolan                  22000.0
# 96       Christopher Nolan                  22000.0
# 97       Christopher Nolan                  22000.0
# 3646     Christopher Nolan                  22000.0
# 1222     Christopher Nolan                  22000.0
# 66       Christopher Nolan                  22000.0
# 3        Christopher Nolan                  22000.0
# 428          David Fincher                  21000.0

# %%
# Hometask 1
TopRich_movies =  movie[movie.country=='USA'][['movie_title', 'budget']].sort_values('budget', ascending=False).head(10)
TopRich_movies
# Out:
#                                     movie_title       budget
# 1      Pirates of the Caribbean: At World's End  300000000.0
# 5                                   John Carter  263700000.0
# 7                                       Tangled  260000000.0
# 6                                  Spider-Man 3  258000000.0
# 18  Pirates of the Caribbean: On Stranger Tides  250000000.0
# 3                         The Dark Knight Rises  250000000.0
# 8                       Avengers: Age of Ultron  250000000.0
# 10           Batman v Superman: Dawn of Justice  250000000.0
# 27                   Captain America: Civil War  250000000.0
# 0                                        Avatar  237000000.0

# %%
# Hometask 2
TopPoore_movies =  movie[movie.country=='USA'][['movie_title','budget']].sort_values('budget', ascending=True).head(10)
TopPoore_movies
# Out:
#                movie_title   budget
# 4684             Tarnation    218.0
# 4915     My Date with Drew   1100.0
# 4913  A Plague So Pleasant   1400.0
# 4909       The Mongol King   3250.0
# 4908           El Mariachi   7000.0
# 4906                Primer   7000.0
# 4910             Newlyweds   9000.0
# 4898        Pink Flamingos  10000.0
# 2316             The Touch  13000.0
# 4678   Paranormal Activity  15000.0

# %%
# Hometask 3
movie.groupby(['title_year']).size().sort_values(ascending=False).head(10)
# Out:
# title_year
# 2009.0    253
# 2014.0    243
# 2006.0    233
# 2013.0    231
# 2010.0    225
# 2011.0    224
# 2008.0    223
# 2005.0    216
# 2012.0    214
# 2015.0    211
# dtype: int64

# %%
BlackWhite =  movie[movie.color=='Black and White'][['movie_title', 'director_name','actor_1_name', 'actor_2_name',
    'actor_3_name','color']].sort_values('color', ascending=True).head(10)
BlackWhite
# Out:
#                        movie_title  director_name     actor_1_name  \
# 111                   Pearl Harbor    Michael Bay  Jennifer Garner
# 4170                   The Hustler  Robert Rossen  George C. Scott
# 4171                     Boom Town    Jack Conway      Hedy Lamarr
# 4178         Gentleman's Agreement     Elia Kazan   Dean Stockwell
# 4181      Alexander's Ragtime Band     Henry King     Tyrone Power
# 4197     In the Shadow of the Moon  David Sington  John F. Kennedy
# 4199            Inside Deep Throat  Fenton Bailey   Hugh M. Hefner
# 4210       24 7: Twenty Four Seven  Shane Meadows      Bob Hoskins
# 4235        The Lady from Shanghai   Orson Welles    Rita Hayworth
# 4240  The Ghastly Love of Johnny X   Paul Bunnell     Kate Maberly
#
#          actor_2_name       actor_3_name            color
# 111        Jaime King               Mako  Black and White
# 4170   Jackie Gleason    Murray Hamilton  Black and White
# ...

# %%
Popular =  movie[movie.title_year==2015][['movie_title', 'director_name','actor_1_name', 'actor_2_name',
    'actor_3_name','title_year']].sort_values('title_year', ascending=True).head(10)
Popular
# Out:
#                                           movie_title    director_name  \
# 2                                             Spectre       Sam Mendes
# 3730                                          Area 51        Oren Peli
# 3739                                    Christmas Eve      Mitch Davis
# 3745                                  Running Forever     Mike Mayhall
# 3747                           Navy Seals vs. Zombies  Stanton Barrett
# 3796  R.L. Stine's Monsterville: The Cabinet of Souls    Peter DeLuise
# 3819                                           Maggie     Henry Hobson
# 3823                                The Boy Next Door        Rob Cohen
# 3856                                           Zipper    Mora Stephens
# 3906                                 Chain of Command   Kevin Carraway
#
#             actor_1_name            actor_2_name       actor_3_name  \
# 2        Christoph Waltz            Rory Kinnear   Stephanie Sigman
# ...

# %%
JC_movie = movie[movie.actor_1_name.isin(['Christian Bale', ['Robert Downey Jr'], ['Scarlett Johansson'], ['Matthew McConaughey']])].sort_values('title_year', ascending=True).head(10)
JC_movie
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 2587  Color  Gillian Armstrong                    27.0     115.0
# 830   Color       Mike Gabriel                    92.0      84.0
# 3251  Color        Todd Haynes                   103.0     124.0
# 892   Color     John Singleton                   160.0      99.0
# 3321  Color        Mary Harron                   288.0     102.0
# 823   Color        John Madden                    96.0     131.0
# 761   Color         Rob Bowman                   138.0     101.0
# 2300  Color        Kurt Wimmer                   146.0     107.0
# 3708  Color      Brad Anderson                   204.0      94.0
# 2028  Color     Hayao Miyazaki                   212.0     119.0
#
#       director_facebook_likes  actor_3_facebook_likes          actor_2_name  \
# 2587                     44.0                   902.0         Kirsten Dunst
# 830                      12.0                   752.0          Frank Welker
# ...

# %%
movie[(movie['aspect_ratio'] > 1.5)].head(10)
movie
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 4       NaN        Doug Walker                     NaN       NaN
# ...     ...                ...                     ...       ...
# 4911  Color        Scott Smith                     1.0      87.0
# 4912  Color                NaN                    43.0      43.0
# 4913  Color   Benjamin Roberds                    13.0      76.0
# 4914  Color        Daniel Hsia                    14.0     100.0
# 4915  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                         0.0                   855.0  Joel David Moore
# ...

# %%
TopMovies =  movie[['movie_title','imdb_score']].sort_values('imdb_score',ascending=False).head(10)
TopMovies
# Out:
#                                         movie_title  imdb_score
# 2725                               Towering Inferno         9.5
# 1920                       The Shawshank Redemption         9.3
# 3402                                  The Godfather         9.2
# 2779                                        Dekalog         9.1
# 4312                           Kickboxer: Vengeance         9.1
# 3415                                          Fargo         9.0
# 2791                         The Godfather: Part II         9.0
# 66                                  The Dark Knight         9.0
# 1857                               Schindler's List         8.9
# 335   The Lord of the Rings: The Return of the King         8.9

# %%
movie = pd.read_csv('dataSet/movie.csv')
movie2= movie[['movie_title', 'imdb_score', 'budget']]
movie2.head()
# Out:
#                                   movie_title  imdb_score       budget
# 0                                      Avatar         7.9  237000000.0
# 1    Pirates of the Caribbean: At World's End         7.1  300000000.0
# 2                                     Spectre         6.8  245000000.0
# 3                       The Dark Knight Rises         8.5  250000000.0
# 4  Star Wars: Episode VII - The Force Awakens         7.1          NaN

# %%
(movie.nlargest(100, 'imdb_score').nsmallest(5, 'budget'))
# Out:
#                 color          director_name  num_critic_for_reviews  \
# 4804            Color              Cary Bell                     NaN
# 4801            Color           Majid Majidi                    46.0
# 4706  Black and White           Sidney Lumet                   177.0
# 4550            Color         Asghar Farhadi                   354.0
# 4636            Color  Marius A. Markevicius                    26.0
#
#       duration  director_facebook_likes  actor_3_facebook_likes  \
# 4804      78.0                      0.0                     0.0
# 4801      89.0                    373.0                    27.0
# 4706      96.0                      0.0                   253.0
# 4550     123.0                      0.0                   620.0
# 4636      89.0                      6.0                     8.0
#
#                 actor_2_name  actor_1_facebook_likes      gross  \
# 4804            Stacie Evans                     0.0        NaN
# ...

# %%
try:
    a = np.array([[1,2,3], [45,78,2]])
    print(type([1,2,3]))
    print(type(a))
    print(a.shape)
    print(a[0,2], a[1,1], a[1,2])
    a[0] = 5
    print(a)
except Exception as ex:
    print(f"Error: {ex}")
# Out:
# <class 'list'>
# <class 'numpy.ndarray'>
# (2, 3)
# 3 78 2
# [[ 5  5  5]
#  [45 78  2]]

# %%
b = np.array([[1,2,3], [4,5,6]])
print()

# %%
a = np.random.randint(2, 75, size=(2,6))
print(a)
# Out:
# [[61  7  8 52 42 57]
#  [34 64 56 24 58 25]]

# %%
s=np.random.randint(1,4)
b=np.random.randint(10, 100, size = (s, s))
print(np.sum(b))
print(np.max(b))
# Out:
# 43
# 43

# %%
import matplotlib as plt

# %%
data = pd.read_csv('dataSet/titanic_train.csv')

# %%
data.describe()
# Out:
#        Unnamed: 0  PassengerId    Survived      Pclass         Age  \
# count  891.000000   891.000000  891.000000  891.000000  714.000000
# mean   445.000000   446.000000    0.383838    2.308642   29.699118
# std    257.353842   257.353842    0.486592    0.836071   14.526497
# min      0.000000     1.000000    0.000000    1.000000    0.420000
# 25%    222.500000   223.500000    0.000000    2.000000   20.125000
# 50%    445.000000   446.000000    0.000000    3.000000   28.000000
# 75%    667.500000   668.500000    1.000000    3.000000   38.000000
# max    890.000000   891.000000    1.000000    3.000000   80.000000
#
#             SibSp       Parch        Fare
# count  891.000000  891.000000  891.000000
# mean     0.523008    0.381594   32.204208
# std      1.102743    0.806057   49.693429
# min      0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    7.910400
# 50%      0.000000    0.000000   14.454200
# 75%      1.000000    0.000000   31.000000
# ...

# %%
data[(data["Embarked"] == "C") & (data.Fare > 500)].head(100)
# Out:
#      Unnamed: 0  PassengerId  Survived  Pclass  \
# 258         258          259         1       1
# 679         679          680         1       1
# 737         737          738         1       1
#
#                                    Name  Gender   Age  SibSp  Parch    Ticket  \
# 258                    Ward, Miss. Anna  female  35.0      0      0  PC 17755
# 679  Cardeza, Mr. Thomas Drake Martinez    male  36.0      0      1  PC 17755
# 737              Lesurer, Mr. Gustave J    male  35.0      0      0  PC 17755
#
#          Fare        Cabin Embarked
# 258  512.3292          NaN        C
# 679  512.3292  B51 B53 B55        C
# 737  512.3292         B101        C

# %%
data[(data["Embarked"] == "C") & (data.Fare > 500)].sort_values(by="Fare", ascending = False).head()
# Out:
#      Unnamed: 0  PassengerId  Survived  Pclass  \
# 258         258          259         1       1
# 679         679          680         1       1
# 737         737          738         1       1
#
#                                    Name  Gender   Age  SibSp  Parch    Ticket  \
# 258                    Ward, Miss. Anna  female  35.0      0      0  PC 17755
# 679  Cardeza, Mr. Thomas Drake Martinez    male  36.0      0      1  PC 17755
# 737              Lesurer, Mr. Gustave J    male  35.0      0      0  PC 17755
#
#          Fare        Cabin Embarked
# 258  512.3292          NaN        C
# 679  512.3292  B51 B53 B55        C
# 737  512.3292         B101        C

# %%
age = data['Age']
age.plot(kind = 'hist')
age.plot(kind = 'bar')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
age = data['Age']
age.plot(kind = 'hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   891 non-null    int64
#  1   PassengerId  891 non-null    int64
#  2   Survived     891 non-null    int64
#  3   Pclass       891 non-null    int64
#  4   Name         891 non-null    object
#  5   Gender       891 non-null    object
#  6   Age          714 non-null    float64
#  7   SibSp        891 non-null    int64
#  8   Parch        891 non-null    int64
#  9   Ticket       891 non-null    object
#  10  Fare         891 non-null    float64
#  11  Cabin        204 non-null    object
#  12  Embarked     889 non-null    object
# dtypes: float64(2), int64(6), object(5)
# memory usage: 90.6+ KB

# %%
cols = ['Name', 'Age', 'Survired']
data.filter(items=cols).head(300)
# Out:
#                                                   Name   Age
# 0                              Braund, Mr. Owen Harris  22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 2                               Heikkinen, Miss. Laina  26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0
# 4                             Allen, Mr. William Henry  35.0
# ..                                                 ...   ...
# 295                                  Lewy, Mr. Ervin G   NaN
# 296                                 Hanna, Mr. Mansour  23.5
# 297                       Allison, Miss. Helen Loraine   2.0
# 298                              Saalfeld, Mr. Adolphe   NaN
# 299    Baxter, Mrs. James (Helene DeLaudeniere Chaput)  50.0
#
# [300 rows x 2 columns]

# %%
data.isnull().sum()
# Out:
# Unnamed: 0       0
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Gender           0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
data.groupby('Gender').size()
# Out:
# Gender
# female    314
# male      577
# dtype: int64

# %%
def age_category(age):
    """
    < 30 -> 1
    >= 30, <55 -> 2
    >= 55 -> 3
    """
    if age < 30:
        return 1
    elif age < 55:
        return 2
    else:
        return 3

# %%
age_categories = age_category

# %%
filt = data['Gender'] == 'female'
data.loc[filt, 'Gender'].size
# Out:
# 314

# %%
data[data['Gender']=='male']['Pclass'].value_counts()[2]
# Out:
# 108

# %%
data.groupby(['Pclass','Gender']).size()
# Out:
# Pclass  Gender
# 1       female     94
#         male      122
# 2       female     76
#         male      108
# 3       female    144
#         male      347
# dtype: int64

# %%
filt = (data['Gender'] == 'male')
data[filt].groupby(by = 'Pclass').size()[2]
# Out:
# 108

# %%
age_series=data[data['Survived']==1].groupby('Age').size()
print(age_series[age_series.index<=30].sum()/age_series.sum())
print(age_series[age_series.index>=60].sum()/age_series.sum())

# %%
print(data[data['Age'] <= 30].groupby(['Survived']).size())
print(data[data['Age'] >= 60].groupby(['Survived']).size())
# Out:
# Survived
# 0    243
# 1    166
# dtype: int64
# Survived
# 0    19
# 1     7
# dtype: int64

# %%
survYoung = data['Survived'][data['Age'] < 30].size
survPerc = survYoung/data['Survived'].size*100
print(survYoung)
print(survPerc)
# Out:
# 384
# 43.09764309764309

# %%
filt = (data['Survived'] == 1)
survived_num = data[filt].size
print(f'All survived: {survived_num}')
filt = ((data['Survived'] == 1) & (data["Age"] < 30))
print(f"Young: {data.loc[filt, 'Age'].size/survived_num}")
filt = ((data['Survived'] == 1) & (data["Age"] > 60))
print(f"Old: {data.loc[filt, 'Age'].size/survived_num}")
# Out:
# All survived: 4788
# Young: 0.03258145363408521
# Old: 0.0010442773600668337

# %%
print(data[(data['Survived']==1)&(data['Age']<30)]['Age'].count()/data[data['Age']<30]['Age'].count()*100)
print(data[(data['Survived']==1)&(data['Age']>60)]['Age'].count()/data[data['Age']>60]['Age'].count()*100)
# Out:
# 40.625
# 22.727272727272727

# %%
g=data.groupby('Gender').size()
g['female'].sum()/g.sum()
# Out:
# 0.35241301907968575

# %%
#true result
fm = data[(data['Survived']==1) & (data['Gender']=="female")].groupby(['Gender']).size().sum()
fmall = data[(data['Gender']=="female")].groupby(['Gender']).size().sum()
print((fm/fmall)*100)
fm = data[(data['Survived']==1) & (data['Gender']=="male")].groupby(['Gender']).size().sum()
fmall = data[(data['Gender']=="male")].groupby(['Gender']).size().sum()
print((fm/fmall)*100)
# Out:
# 74.20382165605095
# 18.890814558058924

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    891 non-null    int64
#  1   PassengerId   891 non-null    int64
#  2   Survived      891 non-null    int64
#  3   Pclass        891 non-null    int64
#  4   Name          891 non-null    object
#  5   Gender        891 non-null    object
#  6   Age           714 non-null    float64
#  7   SibSp         891 non-null    int64
#  8   Parch         891 non-null    int64
#  9   Ticket        891 non-null    object
#  10  Fare          891 non-null    float64
#  11  Cabin         204 non-null    object
#  12  Embarked      889 non-null    object
#  13  Age_category  891 non-null    int64
# dtypes: float64(2), int64(7), object(5)
# memory usage: 97.6+ KB

# %%
titanic = pd.read_csv('dataSet/titanic.csv')

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
# a = 5
# b = 4
# c = 9
a, b, c = input().split() # строка не нужна, если переменные уже определены
a, b, c = c, a, b
print(a, b, c)

# %%
a, b, c = map(int, input().split())
print("A:", a, "B:", b, "C:", c)
a, b, c = c, a, b
print("A:", a, "B:", b, "C:", c)

# %%
s = list(map(str, input().split()))

print(s[0] + ' ' + s[1][0] + '.')

# %%
hell
# Out:
#        yrh&6      ohku         q      hfxx   umeca-4       apj         g  \
# 0   0.288397  0.911359  0.488069  0.074599  0.016124  0.090555  0.560810
# 1   0.861276  0.134987  0.701885  0.897921  0.507115  0.740151  0.963179
# 2   0.775577  0.832874  0.862665  0.831049  0.003274  0.703112  0.509795
# 3   0.857910  0.555818  0.598305  0.473988  0.784139  0.427963  0.725103
# 4   0.748652  0.451725  0.252619  0.584361  0.011265  0.051115  0.755444
# ..       ...       ...       ...       ...       ...       ...       ...
# 95  0.665300  0.744322  0.377087  0.809735  0.220817  0.248306  0.131914
# 96  0.344394  0.182979  0.590196  0.483025  0.474131  0.031048  0.672095
# 97  0.694568  0.507591  0.328004  0.333993  0.091637  0.356788  0.541017
# 98  0.692840  0.220333  0.729843  0.202430  0.360106  0.980271  0.913669
# 99  0.391447  0.989147  0.011527  0.894302  0.669284  0.158220  0.283287
#
#     ijvnixxo  kudbpyw-3    upubjv  ...        fi   clsruyy       g&6  \
# ...

# %%
selected_columns = hell.filter(like='-')
selected_columns
# Out:
#      umeca-4  kudbpyw-3       g-3       v-9     fla-6  hwtbyrkp-5
# 0   0.016124   0.430787  0.202407  0.725508  0.305076    0.979296
# 1   0.507115   0.671662  0.864249  0.867818  0.358859    0.160520
# 2   0.003274   0.286411  0.928865  0.719159  0.340235    0.734612
# 3   0.784139   0.863717  0.175446  0.554744  0.049325    0.621132
# 4   0.011265   0.206172  0.044151  0.163643  0.048806    0.437836
# ..       ...        ...       ...       ...       ...         ...
# 95  0.220817   0.434444  0.601738  0.146333  0.918888    0.216499
# 96  0.474131   0.176011  0.359793  0.104707  0.257690    0.066934
# 97  0.091637   0.871606  0.121075  0.907699  0.313184    0.788592
# 98  0.360106   0.172385  0.015285  0.019571  0.060751    0.403166
# 99  0.669284   0.701505  0.481430  0.024944  0.644989    0.702003
#
# [100 rows x 6 columns]

# %%
selected_columns=hell[hell.columns[hell.columns.str.contains('-')]]
selected_columns
# Out:
#      umeca-4  kudbpyw-3       g-3       v-9     fla-6  hwtbyrkp-5
# 0   0.016124   0.430787  0.202407  0.725508  0.305076    0.979296
# 1   0.507115   0.671662  0.864249  0.867818  0.358859    0.160520
# 2   0.003274   0.286411  0.928865  0.719159  0.340235    0.734612
# 3   0.784139   0.863717  0.175446  0.554744  0.049325    0.621132
# 4   0.011265   0.206172  0.044151  0.163643  0.048806    0.437836
# ..       ...        ...       ...       ...       ...         ...
# 95  0.220817   0.434444  0.601738  0.146333  0.918888    0.216499
# 96  0.474131   0.176011  0.359793  0.104707  0.257690    0.066934
# 97  0.091637   0.871606  0.121075  0.907699  0.313184    0.788592
# 98  0.360106   0.172385  0.015285  0.019571  0.060751    0.403166
# 99  0.669284   0.701505  0.481430  0.024944  0.644989    0.702003
#
# [100 rows x 6 columns]
