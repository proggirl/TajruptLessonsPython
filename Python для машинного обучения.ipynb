# %% [markdown]
# <img src = "images/pandas.png" align = "right"><span style="color: darkgreen; font-size: 2.5em">Библиотека Pandas</span>

# %% [markdown]
# <h3>Что такое Pandas и зачем он нужен</h3>
# <p><strong style="color: darkred">Pandas</strong> — это библиотека на языке Python, созданная для анализа и обработки данных. Имеет открытый исходный код и поддерживается разработчиками Anaconda. Эта библиотека хорошо подходит для структурированных (табличных) данных.</p>

# %% [markdown]
# #### Ядром pandas являются две структуры данных, в которых происходят все операции:
#
# <li>Series
# <li>Dataframes

# %% [markdown]
# <p style> <strong>Series</strong> — это объект библиотеки pandas, спроектированный для представления одномерных структур данных, похожих на массивы, но с дополнительными возможностями. Его структура проста, состоит из двух связанных между собой массивов. Основной содержит данные (данные любого типа NumPy), а в дополнительном, index, хранятся метки.

# %%
import pandas as pd
s = pd.Series([12,-4,7,9])
s
# Out:
# 0    12
# 1    -4
# 2     7
# 3     9
# dtype: int64

# %% [markdown]
# <p>Однако лучше создавать Series, используя метки с неким смыслом, чтобы в будущем отделять и идентифицировать данные вне зависимости от того, в каком порядке они хранятся.
#
# В таком случае необходимо будет при вызове конструктора включить параметр index и присвоить ему массив строк с метками.

# %%
s = pd.Series(['Aziza',28,165,53], index=['name','age','height','weight'])
# s.values просмотр значений
# s.index просмотр индекса
s
# Out:
# name      Aziza
# age          28
# height      165
# weight       53
# dtype: object

# %%
d = pd.Series([14, 25, 63, -96])
d[d>50]
# Out:
# 2    63
# dtype: int64

# %% [markdown]
# <h3 style="color:darkblue">1. Создаём датафреймы с нуля</h3>
# Для начала загрузим библиотеку pandas, сокращенно будем обращаться к ней pd.

# %%
import pandas as pd #импорт библиотеки pandas

# %% [markdown]
# Если вы работаете не через Anaconda, загружайте Pandas командой pip3 install pandas.
#
# В Pandas данные представлены в виде датафрейма, или таблицы с данными. Её можно создать с нуля, например, из словарей, списков или кортежей.
#
# Создадим свой первый датафрейм для трех крупнейших городов Республики Таджикистан. Перед нами словарь, в котором ключами являются city и population, а значениями — списки с названиями этих городов и численностью населения, которая им соответствует.

# %%
dict_city = {'city' : ['Dushanbe', 'Khudzhand', 'Bokhtar'],
            'population' : [864400, 183600, 111800]}
df = pd.DataFrame(dict_city)
df
# Out:
#         city  population
# 0   Dushanbe      864400
# 1  Khudzhand      183600
# 2    Bokhtar      111800

# %% [markdown]
# <hr>

# %% [markdown]
# Также можно создать датафрейм из списка списков.

# %%
list_city = [['Dushanbe', 'Khudzhand', 'Bokhtar'],
            [864400, 183600, 111800]]
df = pd.DataFrame(list_city)
df
# Out:
#           0          1        2
# 0  Dushanbe  Khudzhand  Bokhtar
# 1    864400     183600   111800

# %%
df = pd.DataFrame(list_city).T   # Транспонирование (меянем строки и столбцы местами)
df
# Out:
#            0       1
# 0   Dushanbe  864400
# 1  Khudzhand  183600
# 2    Bokhtar  111800

# %% [markdown]
# <h3 style="color:darkblue">2. Создаем датафрейм из файла</h3>

# %%
airports = pd.read_csv('dataSet/airports.csv')
airport_freq = pd.read_csv('dataSet/airport-frequencies.csv')
runways = pd.read_csv('dataSet/runways.csv')

# %%
airports  # SELECT * FROM airports;
# Out:
#            id    ident            type  \
# 0        6523      00A        heliport
# 1      323361     00AA   small_airport
# 2        6524     00AK   small_airport
# 3        6525     00AL   small_airport
# 4        6526     00AR          closed
# 5      322127     00AS   small_airport
# 6        6527     00AZ   small_airport
# 7        6528     00CA   small_airport
# 8      324424     00CL   small_airport
# 9      322658     00CN        heliport
# 10       6529     00CO          closed
# 11       6531     00FA   small_airport
# 12       6532     00FD        heliport
# 13       6533     00FL   small_airport
# 14       6534     00GA   small_airport
# 15       6535     00GE        heliport
# 16       6536     00HI        heliport
# 17       6537     00ID   small_airport
# 18     322581     00IG   small_airport
# 19       6538     00II          closed
# 20       6539     00IL   small_airport
# 21       6540     00IN        heliport
# 22       6541     00IS   small_airport
# 23       6542     00KS   small_airport
# 24       6543     00KY   small_airport
# 25      45437     00LA        heliport
# 26       6544     00LL        heliport
# 27       6545     00LS   small_airport
# 28       6546     00MD   small_airport
# 29       6547     00MI        heliport
# ...       ...      ...             ...
# 64123  327349     ZYDU  medium_airport
# 64124  324338     ZYFX   small_airport
# 64125  313994     ZYFY  medium_airport
# 64126  335271     ZYGH   small_airport
# 64127   27238     ZYHB   large_airport
# 64128   31576     ZYHE  medium_airport
# 64129   31701     ZYJL   small_airport
# 64130   27239     ZYJM  medium_airport
# 64131  327450     ZYJS  medium_airport
# 64132  313337     ZYJX  medium_airport
# 64133   31706     ZYJZ   small_airport
# 64134  307012     ZYLD  medium_airport
# 64135  300516     ZYLS  medium_airport
# 64136  335272     ZYLY   small_airport
# 64137   27240     ZYMD  medium_airport
# 64138  301193     ZYMH  medium_airport
# 64139   27241     ZYQQ  medium_airport
# 64140  327451     ZYSQ  medium_airport
# 64141  307017     ZYTH   small_airport
# 64142   27242     ZYTL   large_airport
# 64143  307013     ZYTN  medium_airport
# 64144   27243     ZYTX   large_airport
# 64145  342103     ZYXW          closed
# 64146   27244     ZYYJ  medium_airport
# 64147  317861     ZYYK  medium_airport
# 64148   32753     ZYYY  medium_airport
# 64149   46378  ZZ-0001        heliport
# 64150  307326  ZZ-0002   small_airport
# 64151  342102     ZZZW          closed
# 64152  313629     ZZZZ   small_airport
#
#                                            name  latitude_deg  longitude_deg  \
# 0                             Total Rf Heliport     40.070801     -74.933601
# 1                          Aero B Ranch Airport     38.704022    -101.473911
# 2                                  Lowell Field     59.949200    -151.695999
# 3                                  Epps Airpark     34.864799     -86.770302
# 4            Newport Hospital & Clinic Heliport     35.608700     -91.254898
# 5                                Fulton Airport     34.942803     -97.818019
# 6                                Cordes Airport     34.305599    -112.165001
# 7                       Goldstone (GTS) Airport     35.354740    -116.885329
# 8                           Williams Ag Airport     39.427188    -121.763427
# 9               Kitchen Creek Helibase Heliport     32.727374    -116.459742
# 10                                   Cass Field     40.622202    -104.344002
# 11                          Grass Patch Airport     28.645500     -82.219002
# 12                           Ringhaver Heliport     28.846600     -82.345398
# 13                            River Oak Airport     27.230900     -80.969200
# 14                             Lt World Airport     33.767502     -84.068298
# 15                             Caffrey Heliport     33.889245     -84.737930
# 16                           Kaupulehu Heliport     19.832715    -155.980233
# 17                         Delta Shores Airport     48.145302    -116.213997
# 18                                Goltl Airport     39.724028    -101.395994
# 19           Bailey Generation Station Heliport     41.644501     -87.122803
# 20                               Hammer Airport     41.978401     -89.560402
# 21              St Mary Medical Center Heliport     41.511398     -87.260597
# 22            Hayenga's Cant Find Farms Airport     40.025600     -89.122902
# 23                          Hayden Farm Airport     38.727798     -94.930496
# 24                        Robbins Roost Airport     37.409401     -84.619698
# 25            Shell Chemical East Site Heliport     30.191944     -90.980833
# 26                   Ac & R Components Heliport     39.665298     -89.705597
# 27                              Lejeune Airport     30.136299     -92.429398
# 28                                 Slater Field     38.757099     -75.753799
# 29                        Dow Chemical Heliport     43.949402     -86.416702
# ...                                         ...           ...            ...
# 64123                  Wudalianchi Dedu Airport     48.445000     126.133000
# 64124                             Fuxin Airport     42.069014     121.718122
# 64125                             Dongji Aiport     48.199494     134.366447
# 64126                             Genhe Airport     50.700277     121.382500
# 64127                           Taiping Airport     45.623402     126.250000
# 64128                       Heihe Aihui Airport     50.171621     127.308884
# 64129                             Jilin Airport     44.002201     126.396004
# 64130                           Jiamusi Airport     46.843399     130.464996
# 64131                      Jiansanjiang Airport     47.110000     132.660278
# 64132                    Jixi Xingkaihu Airport     45.293000     131.193000
# 64133               Jinzhou Xiaolingzi Air Base     41.101398     121.061996
# 64134                             Lindu Airport     47.752056     129.019125
# 64135                      Yushu Batang Airport     32.836389      97.036389
# 64136                          Liaoyang Airbase     41.277976     123.078729
# 64137  Mudanjiang Hailang International Airport     44.524101     129.569000
# 64138                           Gu-Lian Airport     52.912778     122.430000
# 64139                  Qiqihar Sanjiazi Airport     47.239601     123.917999
# 64140                 Songyuan Chaganhu Airport     44.938114     124.550178
# 64141                              Tahe Airport     52.224444     124.720222
# 64142   Dalian Zhoushuizi International Airport     38.965698     121.539001
# 64143                 Tonghua Sanyuanpu Airport     42.253889     125.703333
# 64144    Shenyang Taoxian International Airport     41.639801     123.483002
# 64145                         Mt Logan Airstrip     60.792990    -138.694027
# 64146               Yanji Chaoyangchuan Airport     42.882801     129.451004
# 64147                     Yingkou Lanqi Airport     40.542524     122.358600
# 64148                   Shenyang Dongta Airport     41.784401     123.496002
# 64149                           Sealand Helipad     51.894444       1.482500
# 64150                 Glorioso Islands Airstrip    -11.584278      47.296389
# 64151                    Scandium City Heliport     69.355287    -138.939310
# 64152                    Satsuma Iōjima Airport     30.784722     130.270556
#
#        elevation_ft continent iso_country iso_region  \
# 0              11.0       NaN          US      US-PA
# 1            3435.0       NaN          US      US-KS
# 2             450.0       NaN          US      US-AK
# 3             820.0       NaN          US      US-AL
# 4             237.0       NaN          US      US-AR
# 5            1100.0       NaN          US      US-OK
# 6            3810.0       NaN          US      US-AZ
# 7            3038.0       NaN          US      US-CA
# 8              87.0       NaN          US      US-CA
# 9            3350.0       NaN          US      US-CA
# 10           4830.0       NaN          US      US-CO
# 11             53.0       NaN          US      US-FL
# 12             25.0       NaN          US      US-FL
# 13             35.0       NaN          US      US-FL
# 14            700.0       NaN          US      US-GA
# 15            957.0       NaN          US      US-GA
# 16             43.0       NaN          US      US-HI
# 17           2064.0       NaN          US      US-ID
# 18           3359.0       NaN          US      US-KS
# 19            600.0       NaN          US      US-IN
# 20            840.0       NaN          US      US-IL
# 21            634.0       NaN          US      US-IN
# 22            820.0       NaN          US      US-IL
# 23           1100.0       NaN          US      US-KS
# 24           1265.0       NaN          US      US-KY
# 25             15.0       NaN          US      US-LA
# 26            600.0       NaN          US      US-IL
# 27             12.0       NaN          US      US-LA
# 28             45.0       NaN          US      US-MD
# 29            588.0       NaN          US      US-MI
# ...             ...       ...         ...        ...
# 64123         984.0        AS          CN      CN-23
# 64124         548.0        AS          CN      CN-21
# 64125           NaN        AS          CN      CN-23
# 64126        2257.0        AS          CN      CN-15
# 64127         457.0        AS          CN      CN-23
# 64128        1047.0        AS          CN      CN-23
# 64129           NaN        AS          CN      CN-22
# 64130         262.0        AS          CN      CN-23
# 64131           NaN        AS          CN      CN-23
# 64132         760.0        AS          CN      CN-23
# 64133           NaN        AS          CN      CN-21
# 64134         791.0        AS          CN      CN-23
# 64135       12816.0        AS          CN      CN-63
# 64136          57.0        AS          CN      CN-21
# 64137         883.0        AS          CN      CN-23
# 64138        1836.0        AS          CN      CN-23
# 64139         477.0        AS          CN      CN-23
# 64140         459.0        AS          CN      CN-22
# 64141        1240.0        AS          CN      CN-23
# 64142         107.0        AS          CN      CN-21
# 64143        1200.0        AS          CN      CN-22
# 64144         198.0        AS          CN      CN-21
# 64145        1997.0       NaN          CA      CA-YT
# 64146         624.0        AS          CN      CN-22
# 64147           NaN        AS          CN      CN-21
# 64148           NaN        AS          CN      CN-21
# 64149          40.0        EU          GB     GB-ENG
# 64150          11.0        AF          TF     TF-U-A
# 64151           4.0       NaN          CA      CA-YT
# 64152         338.0        AS          JP      JP-46
#
#                                municipality scheduled_service gps_code  \
# 0                                  Bensalem                no      00A
# 1                                     Leoti                no     00AA
# 2                              Anchor Point                no     00AK
# 3                                   Harvest                no     00AL
# 4                                   Newport                no      NaN
# 5                                      Alex                no     00AS
# 6                                    Cordes                no     00AZ
# 7                                   Barstow                no     00CA
# 8                                     Biggs                no     00CL
# 9                               Pine Valley                no     00CN
# 10                               Briggsdale                no      NaN
# 11                                 Bushnell                no     00FA
# 12                                Riverview                no     00FD
# 13                               Okeechobee                no     00FL
# 14                                 Lithonia                no     00GA
# 15                                    Hiram                no     00GE
# 16                              Kailua-Kona                no     00HI
# 17                               Clark Fork                no     00ID
# 18                                 McDonald                no     00IG
# 19                               Chesterton                no      NaN
# 20                                     Polo                no     00IL
# 21                                   Hobart                no     00IN
# 22                                    Kings                no     00IS
# 23                                  Gardner                no     00KS
# 24                                 Stanford                no     00KY
# 25                                 Gonzales                no     00LA
# 26                                  Chatham                no     00LL
# 27                                Esterwood                no     00LS
# 28                             Federalsburg                no     00MD
# 29                                Ludington                no     00MI
# ...                                     ...               ...      ...
# 64123                           Wudalianchi               yes     ZYDU
# 64124                           Xihe, Fuxin                no     ZYFX
# 64125                                Fuyuan               yes     ZYFY
# 64126                              Haolibao                no     ZYGH
# 64127                                Harbin               yes     ZYHB
# 64128                          Aihui, Heihe               yes     ZYHE
# 64129                                 Jilin                no     ZYJL
# 64130                               Jiamusi               yes     ZYJM
# 64131                          Jiansanjiang               yes     ZYJS
# 64132                                  Jixi               yes     ZYJX
# 64133                        Taihe, Jinzhou               yes      NaN
# 64134                                Yichun               yes     ZYLD
# 64135                                 Yushu                no     ZYLS
# 64136                     Taizihe, Liaoyang                no     ZYLY
# 64137                            Mudanjiang               yes     ZYMD
# 64138                                  Mohe               yes     ZYMH
# 64139                               Qiqihar               yes     ZYQQ
# 64140  Qian Gorlos Mongol Autonomous County               yes     ZYSQ
# 64141                                  Tahe                no     ZYTH
# 64142                     Ganjingzi, Dalian               yes     ZYTL
# 64143                               Tonghua               yes     ZYTN
# 64144                      Hunnan, Shenyang               yes     ZYTX
# 64145                     Unorganized Yukon                no     ZYXW
# 64146                                 Yanji               yes     ZYYJ
# 64147                      Laobian, Yingkou               yes     ZYYK
# 64148                      Dadong, Shenyang                no     ZYYY
# 64149                               Sealand                no      NaN
# 64150                      Grande Glorieuse                no      NaN
# 64151                   (Old) Scandium City                no     ZZZW
# 64152                          Mishima-Mura                no     RJX7
#
#       iata_code local_code                   home_link  \
# 0           NaN        00A                         NaN
# 1           NaN       00AA                         NaN
# 2           NaN       00AK                         NaN
# 3           NaN       00AL                         NaN
# 4           NaN        NaN                         NaN
# 5           NaN       00AS                         NaN
# 6           NaN       00AZ                         NaN
# 7           NaN       00CA                         NaN
# 8           NaN       00CL                         NaN
# 9           NaN       00CN                         NaN
# 10          NaN        NaN                         NaN
# 11          NaN       00FA                         NaN
# 12          NaN       00FD                         NaN
# 13          NaN       00FL                         NaN
# 14          NaN       00GA                         NaN
# 15          NaN       00GE                         NaN
# 16          NaN       00HI                         NaN
# 17          NaN       00ID                         NaN
# 18          NaN       00IG                         NaN
# 19          NaN        NaN                         NaN
# 20          NaN       00IL                         NaN
# 21          NaN       00IN                         NaN
# 22          NaN       00IS                         NaN
# 23          NaN       00KS                         NaN
# 24          NaN       00KY                         NaN
# 25          NaN       00LA                         NaN
# 26          NaN       00LL                         NaN
# 27          NaN       00LS                         NaN
# 28          NaN       00MD                         NaN
# 29          NaN       00MI                         NaN
# ...         ...        ...                         ...
# 64123       DTU        NaN                         NaN
# 64124       NaN        NaN                         NaN
# 64125       FYJ        NaN                         NaN
# 64126       NaN        NaN                         NaN
# 64127       HRB        NaN                         NaN
# 64128       HEK        NaN                         NaN
# 64129       JIL        NaN                         NaN
# 64130       JMU        NaN                         NaN
# 64131       JSJ        NaN                         NaN
# 64132       JXA        NaN                         NaN
# 64133       NaN        NaN                         NaN
# 64134       LDS        NaN                         NaN
# 64135       YUS        NaN                         NaN
# 64136       NaN        NaN                         NaN
# 64137       MDG        NaN                         NaN
# 64138       OHE        NaN                         NaN
# 64139       NDG        NaN                         NaN
# 64140       YSQ        NaN                         NaN
# 64141       NaN        NaN                         NaN
# 64142       DLC        NaN                         NaN
# 64143       TNH        NaN                         NaN
# 64144       SHE        NaN                         NaN
# 64145       ZYA       YK90                         NaN
# 64146       YNJ        NaN                         NaN
# 64147       YKH        NaN                         NaN
# 64148       NaN        NaN                         NaN
# 64149       NaN        NaN  http://www.sealandgov.org/
# 64150       NaN        NaN                         NaN
# 64151       ZYW       YK96                         NaN
# 64152       NaN       RJX7                         NaN
#
#                                           wikipedia_link  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# 5                                                    NaN
# 6                                                    NaN
# 7                                                    NaN
# 8                                                    NaN
# 9                                                    NaN
# 10                                                   NaN
# 11                                                   NaN
# 12                                                   NaN
# 13                                                   NaN
# 14                                                   NaN
# 15                                                   NaN
# 16                                                   NaN
# 17                                                   NaN
# 18                                                   NaN
# 19                                                   NaN
# 20                                                   NaN
# 21                                                   NaN
# 22                                                   NaN
# 23                                                   NaN
# 24                                                   NaN
# 25                                                   NaN
# 26                                                   NaN
# 27                                                   NaN
# 28                                                   NaN
# 29                                                   NaN
# ...                                                  ...
# 64123  https://en.wikipedia.org/wiki/Wudalianchi_Dedu...
# 64124                                                NaN
# 64125  https://en.wikipedia.org/wiki/Fuyuan_Dongji_Ai...
# 64126                                                NaN
# 64127  https://en.wikipedia.org/wiki/Harbin_Taiping_I...
# 64128  https://en.wikipedia.org/wiki/Heihe_Aihui_Airport
# 64129  https://en.wikipedia.org/wiki/Jilin_Ertaizi_Ai...
# 64130      https://en.wikipedia.org/wiki/Jiamusi_Airport
# 64131  https://en.wikipedia.org/wiki/Jiansanjiang_Air...
# 64132  https://en.wikipedia.org/wiki/Jixi_Xingkaihu_A...
# 64133  https://en.wikipedia.org/wiki/Jinzhou_Xiaoling...
# 64134  https://en.wikipedia.org/wiki/Yichun_Lindu_Air...
# 64135  https://en.wikipedia.org/wiki/Yushu_Batang_Air...
# 64136                                                NaN
# 64137   https://en.wikipedia.org/wiki/Mudanjiang_Airport
# 64138  https://en.wikipedia.org/wiki/Mohe_Gulian_Airport
# 64139      https://en.wikipedia.org/wiki/Qiqihar_Airport
# 64140  https://en.wikipedia.org/wiki/Songyuan_Chaganh...
# 64141                                                NaN
# 64142  https://en.wikipedia.org/wiki/Dalian_Zhoushuiz...
# 64143  https://en.wikipedia.org/wiki/Tonghua_Sanyuanp...
# 64144  https://en.wikipedia.org/wiki/Shenyang_Taoxian...
# 64145                                                NaN
# 64146  https://en.wikipedia.org/wiki/Yanji_Chaoyangch...
# 64147  https://en.wikipedia.org/wiki/Yingkou_Lanqi_Ai...
# 64148                                                NaN
# 64149  https://en.wikipedia.org/wiki/Principality_of_...
# 64150                                                NaN
# 64151                                                NaN
# 64152  http://wikimapia.org/6705190/Satsuma-Iwo-jima-...
#
#                     keywords
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                       00AR
# 5                        NaN
# 6                        NaN
# 7                        NaN
# 8                        NaN
# 9                        NaN
# 10                      00CO
# 11                       NaN
# 12                       NaN
# 13                       NaN
# 14                       NaN
# 15                       NaN
# 16                       NaN
# 17                       NaN
# 18                       NaN
# 19                      00II
# 20                       NaN
# 21                       NaN
# 22                       NaN
# 23                       NaN
# 24                       NaN
# 25                       NaN
# 26                       NaN
# 27                       NaN
# 28                       NaN
# 29                       NaN
# ...                      ...
# 64123                    NaN
# 64124                    NaN
# 64125                    NaN
# 64126                    根河市
# 64127                    NaN
# 64128                    NaN
# 64129                    NaN
# 64130                    NaN
# 64131                    NaN
# 64132                    NaN
# 64133    Xiaolingzi Air Base
# 64134     Yichun Shi Airport
# 64135                    NaN
# 64136                    NaN
# 64137             Mudanjiang
# 64138                    NaN
# 64139                    NaN
# 64140                    NaN
# 64141                    NaN
# 64142        Dalian Air Base
# 64143  Tonghua Liuhe Airport
# 64144                    NaN
# 64145                    NaN
# 64146                    NaN
# 64147                    NaN
# 64148                    NaN
# 64149   Roughs Tower Helipad
# 64150                    NaN
# 64151                    NaN
# 64152   SATSUMA,IWOJIMA,RJX7
#
# [64153 rows x 18 columns]

# %%
airports.head()   # Первые 5 строк датафрейма SELECT * FROM airports LIMIT 15
# Out:
#         id ident           type                                name  \
# 0     6523   00A       heliport                   Total Rf Heliport
# 1   323361  00AA  small_airport                Aero B Ranch Airport
# 2     6524  00AK  small_airport                        Lowell Field
# 3     6525  00AL  small_airport                        Epps Airpark
# 4     6526  00AR         closed  Newport Hospital & Clinic Heliport
# 5   322127  00AS  small_airport                      Fulton Airport
# 6     6527  00AZ  small_airport                      Cordes Airport
# 7     6528  00CA  small_airport             Goldstone (GTS) Airport
# 8   324424  00CL  small_airport                 Williams Ag Airport
# 9   322658  00CN       heliport     Kitchen Creek Helibase Heliport
# 10    6529  00CO         closed                          Cass Field
# 11    6531  00FA  small_airport                 Grass Patch Airport
# 12    6532  00FD       heliport                  Ringhaver Heliport
# 13    6533  00FL  small_airport                   River Oak Airport
# 14    6534  00GA  small_airport                    Lt World Airport
#
#     latitude_deg  longitude_deg  elevation_ft continent iso_country  \
# 0      40.070801     -74.933601          11.0       NaN          US
# 1      38.704022    -101.473911        3435.0       NaN          US
# 2      59.949200    -151.695999         450.0       NaN          US
# 3      34.864799     -86.770302         820.0       NaN          US
# 4      35.608700     -91.254898         237.0       NaN          US
# 5      34.942803     -97.818019        1100.0       NaN          US
# 6      34.305599    -112.165001        3810.0       NaN          US
# 7      35.354740    -116.885329        3038.0       NaN          US
# 8      39.427188    -121.763427          87.0       NaN          US
# 9      32.727374    -116.459742        3350.0       NaN          US
# 10     40.622202    -104.344002        4830.0       NaN          US
# 11     28.645500     -82.219002          53.0       NaN          US
# 12     28.846600     -82.345398          25.0       NaN          US
# 13     27.230900     -80.969200          35.0       NaN          US
# 14     33.767502     -84.068298         700.0       NaN          US
#
#    iso_region  municipality scheduled_service gps_code iata_code local_code  \
# 0       US-PA      Bensalem                no      00A       NaN        00A
# 1       US-KS         Leoti                no     00AA       NaN       00AA
# 2       US-AK  Anchor Point                no     00AK       NaN       00AK
# 3       US-AL       Harvest                no     00AL       NaN       00AL
# 4       US-AR       Newport                no      NaN       NaN        NaN
# 5       US-OK          Alex                no     00AS       NaN       00AS
# 6       US-AZ        Cordes                no     00AZ       NaN       00AZ
# 7       US-CA       Barstow                no     00CA       NaN       00CA
# 8       US-CA         Biggs                no     00CL       NaN       00CL
# 9       US-CA   Pine Valley                no     00CN       NaN       00CN
# 10      US-CO    Briggsdale                no      NaN       NaN        NaN
# 11      US-FL      Bushnell                no     00FA       NaN       00FA
# 12      US-FL     Riverview                no     00FD       NaN       00FD
# 13      US-FL    Okeechobee                no     00FL       NaN       00FL
# 14      US-GA      Lithonia                no     00GA       NaN       00GA
#
#    home_link wikipedia_link keywords
# 0        NaN            NaN      NaN
# 1        NaN            NaN      NaN
# 2        NaN            NaN      NaN
# 3        NaN            NaN      NaN
# 4        NaN            NaN     00AR
# 5        NaN            NaN      NaN
# 6        NaN            NaN      NaN
# 7        NaN            NaN      NaN
# 8        NaN            NaN      NaN
# 9        NaN            NaN      NaN
# 10       NaN            NaN     00CO
# 11       NaN            NaN      NaN
# 12       NaN            NaN      NaN
# 13       NaN            NaN      NaN
# 14       NaN            NaN      NaN

# %%
airports.head(15)   # Первые 10 строк датафрейма
# Out:
#         id ident           type                                name  \
# 0     6523   00A       heliport                   Total Rf Heliport
# 1   323361  00AA  small_airport                Aero B Ranch Airport
# 2     6524  00AK  small_airport                        Lowell Field
# 3     6525  00AL  small_airport                        Epps Airpark
# 4     6526  00AR         closed  Newport Hospital & Clinic Heliport
# 5   322127  00AS  small_airport                      Fulton Airport
# 6     6527  00AZ  small_airport                      Cordes Airport
# 7     6528  00CA  small_airport             Goldstone (GTS) Airport
# 8   324424  00CL  small_airport                 Williams Ag Airport
# 9   322658  00CN       heliport     Kitchen Creek Helibase Heliport
# 10    6529  00CO         closed                          Cass Field
# 11    6531  00FA  small_airport                 Grass Patch Airport
# 12    6532  00FD       heliport                  Ringhaver Heliport
# 13    6533  00FL  small_airport                   River Oak Airport
# 14    6534  00GA  small_airport                    Lt World Airport
#
#     latitude_deg  longitude_deg  elevation_ft continent iso_country  \
# 0      40.070801     -74.933601          11.0       NaN          US
# 1      38.704022    -101.473911        3435.0       NaN          US
# 2      59.949200    -151.695999         450.0       NaN          US
# 3      34.864799     -86.770302         820.0       NaN          US
# 4      35.608700     -91.254898         237.0       NaN          US
# 5      34.942803     -97.818019        1100.0       NaN          US
# 6      34.305599    -112.165001        3810.0       NaN          US
# 7      35.354740    -116.885329        3038.0       NaN          US
# 8      39.427188    -121.763427          87.0       NaN          US
# 9      32.727374    -116.459742        3350.0       NaN          US
# 10     40.622202    -104.344002        4830.0       NaN          US
# 11     28.645500     -82.219002          53.0       NaN          US
# 12     28.846600     -82.345398          25.0       NaN          US
# 13     27.230900     -80.969200          35.0       NaN          US
# 14     33.767502     -84.068298         700.0       NaN          US
#
#    iso_region  municipality scheduled_service gps_code iata_code local_code  \
# 0       US-PA      Bensalem                no      00A       NaN        00A
# 1       US-KS         Leoti                no     00AA       NaN       00AA
# 2       US-AK  Anchor Point                no     00AK       NaN       00AK
# 3       US-AL       Harvest                no     00AL       NaN       00AL
# 4       US-AR       Newport                no      NaN       NaN        NaN
# 5       US-OK          Alex                no     00AS       NaN       00AS
# 6       US-AZ        Cordes                no     00AZ       NaN       00AZ
# 7       US-CA       Barstow                no     00CA       NaN       00CA
# 8       US-CA         Biggs                no     00CL       NaN       00CL
# 9       US-CA   Pine Valley                no     00CN       NaN       00CN
# 10      US-CO    Briggsdale                no      NaN       NaN        NaN
# 11      US-FL      Bushnell                no     00FA       NaN       00FA
# 12      US-FL     Riverview                no     00FD       NaN       00FD
# 13      US-FL    Okeechobee                no     00FL       NaN       00FL
# 14      US-GA      Lithonia                no     00GA       NaN       00GA
#
#    home_link wikipedia_link keywords
# 0        NaN            NaN      NaN
# 1        NaN            NaN      NaN
# 2        NaN            NaN      NaN
# 3        NaN            NaN      NaN
# 4        NaN            NaN     00AR
# 5        NaN            NaN      NaN
# 6        NaN            NaN      NaN
# 7        NaN            NaN      NaN
# 8        NaN            NaN      NaN
# 9        NaN            NaN      NaN
# 10       NaN            NaN     00CO
# 11       NaN            NaN      NaN
# 12       NaN            NaN      NaN
# 13       NaN            NaN      NaN
# 14       NaN            NaN      NaN

# %%
airports.tail()  # Последние 5 строк датафрейма
# Out:
#            id    ident            type                       name  \
# 64148   32753     ZYYY  medium_airport    Shenyang Dongta Airport
# 64149   46378  ZZ-0001        heliport            Sealand Helipad
# 64150  307326  ZZ-0002   small_airport  Glorioso Islands Airstrip
# 64151  342102     ZZZW          closed     Scandium City Heliport
# 64152  313629     ZZZZ   small_airport     Satsuma Iōjima Airport
#
#        latitude_deg  longitude_deg  elevation_ft continent iso_country  \
# 64148     41.784401     123.496002           NaN        AS          CN
# 64149     51.894444       1.482500          40.0        EU          GB
# 64150    -11.584278      47.296389          11.0        AF          TF
# 64151     69.355287    -138.939310           4.0       NaN          CA
# 64152     30.784722     130.270556         338.0        AS          JP
#
#       iso_region         municipality scheduled_service gps_code iata_code  \
# 64148      CN-21     Dadong, Shenyang                no     ZYYY       NaN
# 64149     GB-ENG              Sealand                no      NaN       NaN
# 64150     TF-U-A     Grande Glorieuse                no      NaN       NaN
# 64151      CA-YT  (Old) Scandium City                no     ZZZW       ZYW
# 64152      JP-46         Mishima-Mura                no     RJX7       NaN
#
#       local_code                   home_link  \
# 64148        NaN                         NaN
# 64149        NaN  http://www.sealandgov.org/
# 64150        NaN                         NaN
# 64151       YK96                         NaN
# 64152       RJX7                         NaN
#
#                                           wikipedia_link              keywords
# 64148                                                NaN                   NaN
# 64149  https://en.wikipedia.org/wiki/Principality_of_...  Roughs Tower Helipad
# 64150                                                NaN                   NaN
# 64151                                                NaN                   NaN
# 64152  http://wikimapia.org/6705190/Satsuma-Iwo-jima-...  SATSUMA,IWOJIMA,RJX7

# %% [markdown]
# Метод df.info() дает описание датафрейма: сколько в нем строк и столбцов, какие типы данных содержатся, сколько не пустых значений (non-null), сколько памяти занимает.

# %%
airports.info()   #информация о датафрейме
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64153 entries, 0 to 64152
# Data columns (total 18 columns):
# id                   64153 non-null int64
# ident                64152 non-null object
# type                 64153 non-null object
# name                 64153 non-null object
# latitude_deg         64153 non-null float64
# longitude_deg        64153 non-null float64
# elevation_ft         52166 non-null float64
# continent            32838 non-null object
# iso_country          63904 non-null object
# iso_region           64153 non-null object
# municipality         58737 non-null object
# scheduled_service    64153 non-null object
# gps_code             42226 non-null object
# iata_code            9264 non-null object
# local_code           31482 non-null object
# home_link            3260 non-null object
# wikipedia_link       10293 non-null object
# keywords             11707 non-null object
# dtypes: float64(3), int64(1), object(14)
# memory usage: 5.4+ MB

# %%
airports.shape  # количество строк и столбцов в датафрейме
# Out:
# (64153, 18)

# %% [markdown]
# <hr style="border: 1px solid green">

# %% [markdown]
# Метод describe дает статистику по числовым столбцам: среднее, максимум и минимум, квартили, стандартное отклонение.

# %%
airports.describe()
# Out:
#                   id  latitude_deg  longitude_deg  elevation_ft
# count   64153.000000  64153.000000   64153.000000  52166.000000
# mean   119764.215828     25.728509     -31.794058   1265.040946
# std    142652.832788     26.711810      83.209752   1622.301789
# min         2.000000    -90.000000    -179.876999  -1266.000000
# 25%     16172.000000      9.811460     -93.251801    209.000000
# 50%     32501.000000     35.535599     -70.652222    726.000000
# 75%    318603.000000     43.224800      17.986111   1550.000000
# max    343464.000000     82.750000     179.975700  22000.000000

# %% [markdown]
# Если нам для статистики нужны не только числовые столбцы, но и все остальные, добавим аргумент all.

# %%
airports.describe(include = 'all')
# Out:
#                    id  ident           type                         name  \
# count    64153.000000  64152          64153                        64153
# unique            NaN  64152              7                        60863
# top               NaN   WI80  small_airport  Centre Hospitalier Heliport
# freq              NaN      1          36245                           84
# mean    119764.215828    NaN            NaN                          NaN
# std     142652.832788    NaN            NaN                          NaN
# min          2.000000    NaN            NaN                          NaN
# 25%      16172.000000    NaN            NaN                          NaN
# 50%      32501.000000    NaN            NaN                          NaN
# 75%     318603.000000    NaN            NaN                          NaN
# max     343464.000000    NaN            NaN                          NaN
#
#         latitude_deg  longitude_deg  elevation_ft continent iso_country  \
# count   64153.000000   64153.000000  52166.000000     32838       63904
# unique           NaN            NaN           NaN         6         244
# top              NaN            NaN           NaN        SA          US
# freq             NaN            NaN           NaN      9162       25640
# mean       25.728509     -31.794058   1265.040946       NaN         NaN
# std        26.711810      83.209752   1622.301789       NaN         NaN
# min       -90.000000    -179.876999  -1266.000000       NaN         NaN
# 25%         9.811460     -93.251801    209.000000       NaN         NaN
# 50%        35.535599     -70.652222    726.000000       NaN         NaN
# 75%        43.224800      17.986111   1550.000000       NaN         NaN
# max        82.750000     179.975700  22000.000000       NaN         NaN
#
#        iso_region municipality scheduled_service gps_code iata_code  \
# count       64153        58737             64153    42226      9264
# unique       2839        30249                 2    41031      9140
# top         US-TX        Seoul                no     SDPS         0
# freq         2801          403             60029        3        65
# mean          NaN          NaN               NaN      NaN       NaN
# std           NaN          NaN               NaN      NaN       NaN
# min           NaN          NaN               NaN      NaN       NaN
# 25%           NaN          NaN               NaN      NaN       NaN
# 50%           NaN          NaN               NaN      NaN       NaN
# 75%           NaN          NaN               NaN      NaN       NaN
# max           NaN          NaN               NaN      NaN       NaN
#
#        local_code                                          home_link  \
# count       31482                                               3260
# unique      29930                                               3245
# top           AMA  http://www.airport.kg/index.php?option=com_con...
# freq            5                                                  4
# mean          NaN                                                NaN
# std           NaN                                                NaN
# min           NaN                                                NaN
# 25%           NaN                                                NaN
# 50%           NaN                                                NaN
# 75%           NaN                                                NaN
# max           NaN                                                NaN
#
#                                            wikipedia_link keywords
# count                                               10293    11707
# unique                                              10220    11422
# top     https://en.wikipedia.org/wiki/List_of_highway_...    Mukho
# freq                                                   14       50
# mean                                                  NaN      NaN
# std                                                   NaN      NaN
# min                                                   NaN      NaN
# 25%                                                   NaN      NaN
# 50%                                                   NaN      NaN
# 75%                                                   NaN      NaN
# max                                                   NaN      NaN

# %% [markdown]
# <hr style="border: 1px solid green">

# %% [markdown]
# <h3 style="color:darkblue">3. Фильтруем датафрейм по названию столбца и индексам</h3>

# %% [markdown]
# Выбрать определенный столбец можно двумя способами:

# %%
airports.name

# %%
airports['name']

# %% [markdown]
# <p style = "font-size: 1.25em">Также можно вывести на экран сразу несколько столбцов, обернув их в двойные квадратные скобки.

# %%
airports[['name', 'iso_country', 'iso_region', 'municipality']]
# Out:
#                                            name iso_country iso_region  \
# 0                             Total Rf Heliport          US      US-PA
# 1                          Aero B Ranch Airport          US      US-KS
# 2                                  Lowell Field          US      US-AK
# 3                                  Epps Airpark          US      US-AL
# 4            Newport Hospital & Clinic Heliport          US      US-AR
# 5                                Fulton Airport          US      US-OK
# 6                                Cordes Airport          US      US-AZ
# 7                       Goldstone (GTS) Airport          US      US-CA
# 8                           Williams Ag Airport          US      US-CA
# 9               Kitchen Creek Helibase Heliport          US      US-CA
# 10                                   Cass Field          US      US-CO
# 11                          Grass Patch Airport          US      US-FL
# 12                           Ringhaver Heliport          US      US-FL
# 13                            River Oak Airport          US      US-FL
# 14                             Lt World Airport          US      US-GA
# 15                             Caffrey Heliport          US      US-GA
# 16                           Kaupulehu Heliport          US      US-HI
# 17                         Delta Shores Airport          US      US-ID
# 18                                Goltl Airport          US      US-KS
# 19           Bailey Generation Station Heliport          US      US-IN
# 20                               Hammer Airport          US      US-IL
# 21              St Mary Medical Center Heliport          US      US-IN
# 22            Hayenga's Cant Find Farms Airport          US      US-IL
# 23                          Hayden Farm Airport          US      US-KS
# 24                        Robbins Roost Airport          US      US-KY
# 25            Shell Chemical East Site Heliport          US      US-LA
# 26                   Ac & R Components Heliport          US      US-IL
# 27                              Lejeune Airport          US      US-LA
# 28                                 Slater Field          US      US-MD
# 29                        Dow Chemical Heliport          US      US-MI
# ...                                         ...         ...        ...
# 64123                  Wudalianchi Dedu Airport          CN      CN-23
# 64124                             Fuxin Airport          CN      CN-21
# 64125                             Dongji Aiport          CN      CN-23
# 64126                             Genhe Airport          CN      CN-15
# 64127                           Taiping Airport          CN      CN-23
# 64128                       Heihe Aihui Airport          CN      CN-23
# 64129                             Jilin Airport          CN      CN-22
# 64130                           Jiamusi Airport          CN      CN-23
# 64131                      Jiansanjiang Airport          CN      CN-23
# 64132                    Jixi Xingkaihu Airport          CN      CN-23
# 64133               Jinzhou Xiaolingzi Air Base          CN      CN-21
# 64134                             Lindu Airport          CN      CN-23
# 64135                      Yushu Batang Airport          CN      CN-63
# 64136                          Liaoyang Airbase          CN      CN-21
# 64137  Mudanjiang Hailang International Airport          CN      CN-23
# 64138                           Gu-Lian Airport          CN      CN-23
# 64139                  Qiqihar Sanjiazi Airport          CN      CN-23
# 64140                 Songyuan Chaganhu Airport          CN      CN-22
# 64141                              Tahe Airport          CN      CN-23
# 64142   Dalian Zhoushuizi International Airport          CN      CN-21
# 64143                 Tonghua Sanyuanpu Airport          CN      CN-22
# 64144    Shenyang Taoxian International Airport          CN      CN-21
# 64145                         Mt Logan Airstrip          CA      CA-YT
# 64146               Yanji Chaoyangchuan Airport          CN      CN-22
# 64147                     Yingkou Lanqi Airport          CN      CN-21
# 64148                   Shenyang Dongta Airport          CN      CN-21
# 64149                           Sealand Helipad          GB     GB-ENG
# 64150                 Glorioso Islands Airstrip          TF     TF-U-A
# 64151                    Scandium City Heliport          CA      CA-YT
# 64152                    Satsuma Iōjima Airport          JP      JP-46
#
#                                municipality
# 0                                  Bensalem
# 1                                     Leoti
# 2                              Anchor Point
# 3                                   Harvest
# 4                                   Newport
# 5                                      Alex
# 6                                    Cordes
# 7                                   Barstow
# 8                                     Biggs
# 9                               Pine Valley
# 10                               Briggsdale
# 11                                 Bushnell
# 12                                Riverview
# 13                               Okeechobee
# 14                                 Lithonia
# 15                                    Hiram
# 16                              Kailua-Kona
# 17                               Clark Fork
# 18                                 McDonald
# 19                               Chesterton
# 20                                     Polo
# 21                                   Hobart
# 22                                    Kings
# 23                                  Gardner
# 24                                 Stanford
# 25                                 Gonzales
# 26                                  Chatham
# 27                                Esterwood
# 28                             Federalsburg
# 29                                Ludington
# ...                                     ...
# 64123                           Wudalianchi
# 64124                           Xihe, Fuxin
# 64125                                Fuyuan
# 64126                              Haolibao
# 64127                                Harbin
# 64128                          Aihui, Heihe
# 64129                                 Jilin
# 64130                               Jiamusi
# 64131                          Jiansanjiang
# 64132                                  Jixi
# 64133                        Taihe, Jinzhou
# 64134                                Yichun
# 64135                                 Yushu
# 64136                     Taizihe, Liaoyang
# 64137                            Mudanjiang
# 64138                                  Mohe
# 64139                               Qiqihar
# 64140  Qian Gorlos Mongol Autonomous County
# 64141                                  Tahe
# 64142                     Ganjingzi, Dalian
# 64143                               Tonghua
# 64144                      Hunnan, Shenyang
# 64145                     Unorganized Yukon
# 64146                                 Yanji
# 64147                      Laobian, Yingkou
# 64148                      Dadong, Shenyang
# 64149                               Sealand
# 64150                      Grande Glorieuse
# 64151                   (Old) Scandium City
# 64152                          Mishima-Mura
#
# [64153 rows x 4 columns]

# %% [markdown]
# <hr style="border: 1px solid green">

# %% [markdown]
# Ещё для выбора столбцов и строк существует методы loc и iloc. Loc — для выбора по названию, iloc — по индексу (порядковому номеру).

# %%
airports.loc[100:105, 'name': 'iso_country']
# Out:
#                                name  latitude_deg  longitude_deg  \
# 100                  Detour Airport     40.843601    -100.653000
# 101                  Moore Airfield     43.644500     -72.086998
# 102  Albert Guido Memorial Heliport     40.741798     -74.137100
# 103          Champion Ranch Airport     33.008611    -104.540278
# 104           Lantana Ranch Airport     38.763901    -119.027000
# 105        Vassar Hospital Heliport     41.692415     -73.936830
#
#      elevation_ft continent iso_country
# 100        3000.0       NaN          US
# 101         835.0       NaN          US
# 102          10.0       NaN          US
# 103        3630.0       NaN          US
# 104        4600.0       NaN          US
# 105         100.0       NaN          US

# %%
airports.iloc[100:105, 0:5]
# Out:
#         id ident           type                            name  latitude_deg
# 100   6612  01NE  small_airport                  Detour Airport     40.843601
# 101   6613  01NH  small_airport                  Moore Airfield     43.644500
# 102   6614  01NJ       heliport  Albert Guido Memorial Heliport     40.741798
# 103  45537  01NM  small_airport          Champion Ranch Airport     33.008611
# 104   6615  01NV  small_airport           Lantana Ranch Airport     38.763901

# %% [markdown]
# <h3 style="color:darkblue">4. Фильтруем датафрейм по условиям</h3>

# %% [markdown]
# Получить данные об аэропортах города Нью-Йорк

# %%
airports[(airports['iso_country'] == 'TJ') & (airports['municipality'] == 'Khujand')]
# Out:
#           id ident            type             name  latitude_deg  \
# 59228  26386  UTDL  medium_airport  Khujand Airport     40.215401
#
#        longitude_deg  elevation_ft continent iso_country iso_region  \
# 59228      69.694702        1450.0        AS          TJ      TJ-SU
#
#       municipality scheduled_service gps_code iata_code local_code home_link  \
# 59228      Khujand               yes     UTDL       LBD        NaN       NaN
#
#                                         wikipedia_link  \
# 59228  https://en.wikipedia.org/wiki/Khudzhand_Airport
#
#                                         keywords
# 59228  Khodjend, Khodzhent, Leninabad, Khudzhand

# %%
TJ = airports[(airports['iso_country'] == 'TJ') & (airports['elevation_ft'] > 2500)]
TJ
# Out:
#            id    ident            type               name  latitude_deg  \
# 53818  300330  TJ-0003   small_airport       Ayni Airport     39.405556
# 53819  300331  TJ-0004   small_airport  Penjikent Airport     39.482222
# 53820  300332  TJ-0005   small_airport       Garm Airport     39.003889
# 53824    6374  TJ-UT44   small_airport    Murghab Airport     38.190399
# 59138    6371     UT1A   small_airport     Isfara Airport     40.120602
# 59140    6373     UT1C   small_airport     Khorog Airport     37.502222
# 59226   26385     UTDD  medium_airport   Dushanbe Airport     38.543301
#
#        longitude_deg  elevation_ft continent iso_country iso_region  \
# 53818      68.522778        4655.0        AS          TJ      TJ-SU
# 53819      67.605556        3400.0        AS          TJ      TJ-SU
# 53820      70.290278        4280.0        AS          TJ      TJ-RR
# 53824      74.024696       11962.0        AS          TJ      TJ-GB
# 59138      70.675201        2814.0        AS          TJ      TJ-SU
# 59140      71.513333        6700.0        AS          TJ      TJ-GB
# 59226      68.824997        2575.0        AS          TJ      TJ-RR
#
#       municipality scheduled_service gps_code iata_code local_code home_link  \
# 53818         Ayni                no      NaN       NaN        NaN       NaN
# 53819    Panjakent                no      NaN       NaN        NaN       NaN
# 53820         Garm                no      NaN       NaN        NaN       NaN
# 53824      Murghab                no      NaN       NaN        NaN       NaN
# 59138       Isfara                no      NaN       NaN        NaN       NaN
# 59140       Khorog                no     UTOD       NaN        NaN       NaN
# 59226     Dushanbe               yes     UTDD       DYU        NaN       NaN
#
#                                        wikipedia_link  \
# 53818                                             NaN
# 53819                                             NaN
# 53820                                             NaN
# 53824                                             NaN
# 59138    https://en.wikipedia.org/wiki/Isfara_Airport
# 59140    https://en.wikipedia.org/wiki/Khorog_Airport
# 59226  https://en.wikipedia.org/wiki/Dushanbe_Airport
#
#                           keywords
# 53818                          NaN
# 53819                          NaN
# 53820                          NaN
# 53824  UT44, Murgab, Мурғоб, مرغاب
# 59138                         UT1A
# 59140                         UT1C
# 59226                          NaN

# %%
try:
    TJ.to_csv("dataSet/TJairports.csv", sep = '\t', encoding = 'utf-8')
except Exception as e:
    print(f"Ошибка: {e}")

# %%
airports[(airports.iso_region == 'US-CA') & (airports.type == 'seaplane_base')]
# Out:
#            id    ident           type  \
# 995      7436      0O0  seaplane_base
# 2524     8877     22CA  seaplane_base
# 6314    12298     5CA9  seaplane_base
# 14444   16514      C39  seaplane_base
# 16860   16830     CN20  seaplane_base
# 19299   17157      E20  seaplane_base
# 25100   17613      H77  seaplane_base
# 34997   21444      L11  seaplane_base
# 42280   23479      O06  seaplane_base
# 46449   24384      S74  seaplane_base
# 52402  341941     STIN  seaplane_base
# 54275  300312      TWH  seaplane_base
# 58583  342286  US-3338  seaplane_base
# 58701  342600  US-3456  seaplane_base
#
#                                                     name  latitude_deg  \
# 995                     San Luis Reservoir Seaplane Base     37.058300
# 2524                      Commodore Center Seaplane Base     37.878893
# 6314                 Konocti  - Clear Lake Seaplane Base     38.977699
# 14444                          Folsom Lake Seaplane Base     38.707199
# 16860                      Ferndale Resort Seaplane Base     39.002998
# 19299                       Lake Berryessa Seaplane Base     38.550979
# 25100                    Bridge Bay Resort Seaplane Base     40.757599
# 34997                         Pebbly Beach Seaplane Base     33.338402
# 42280           Lake Oroville Landing Area Seaplane Base     39.566601
# 46449                            Lost Isle Seaplane Base     38.004101
# 52402  Stinson Beach Seadrift Lagoon Seaplane Base (n...     37.906997
# 54275                    Two Harbors Amphibious Terminal     33.432222
# 58583                          Avalon Port Seaplane Base     33.345260
# 58701                 Lytle Creek Ranger Station Helipad     34.234550
#
#        longitude_deg  elevation_ft continent iso_country iso_region  \
# 995      -121.125999         544.0       NaN          US      US-CA
# 2524     -122.512697           NaN       NaN          US      US-CA
# 6314     -122.718002        1326.0       NaN          US      US-CA
# 14444    -121.133003         466.0       NaN          US      US-CA
# 16860    -122.796997        1326.0       NaN          US      US-CA
# 19299    -122.227682         440.0       NaN          US      US-CA
# 25100    -122.322998        1065.0       NaN          US      US-CA
# 34997    -118.311996           NaN       NaN          US      US-CA
# 42280    -121.468002         900.0       NaN          US      US-CA
# 46449    -121.457001           NaN       NaN          US      US-CA
# 52402    -122.660746           1.0       NaN          US      US-CA
# 54275    -118.508611           NaN       NaN          US      US-CA
# 58583    -118.324329           NaN       NaN          US      US-CA
# 58701    -117.482360        2769.0       NaN          US      US-CA
#
#               municipality scheduled_service gps_code iata_code local_code  \
# 995              Los Banos                no      0O0       NaN        0O0
# 2524           Mill Valley                no     22CA       NaN       22CA
# 6314           Kelseyville                no     5CA9       NaN       5CA9
# 14444               Folsom                no      C39       NaN        C39
# 16860          Kelseyville                no     CN20       NaN       CN20
# 19299                 Napa                no      NaN       NaN        E20
# 25100              Redding                no      H77       NaN        H77
# 34997               Avalon                no     KL11       NaN        L11
# 42280             Oroville                no      O06       NaN        O06
# 46449             Stockton                no      S74       NaN        S74
# 52402  North Stinson Beach                no      NaN       NaN        NaN
# 54275          Two Harbors                no      NaN       TWH        NaN
# 58583               Avalon                no      NaN       NaN        NaN
# 58701          Lytle Creek                no      NaN       NaN        NaN
#
#       home_link wikipedia_link keywords
# 995         NaN            NaN      NaN
# 2524        NaN            NaN      NaN
# 6314        NaN            NaN      NaN
# 14444       NaN            NaN      NaN
# 16860       NaN            NaN      NaN
# 19299       NaN            NaN      NaN
# 25100       NaN            NaN      NaN
# 34997       NaN            NaN      NaN
# 42280       NaN            NaN      NaN
# 46449       NaN            NaN      NaN
# 52402       NaN            NaN      NaN
# 54275       NaN            NaN      NaN
# 58583       NaN            NaN      NaN
# 58701       NaN            NaN      NaN

# %%
airports[(airports.iso_country == 'TJ') | (airports.type == 'large_airport')][['ident', 'name', 'municipality']]
# Out:
#          ident                                               name  \
# 10621     AGGH                      Honiara International Airport
# 12122     AYPY        Port Moresby Jacksons International Airport
# 12628     BIKF                     Keflavik International Airport
# 12675     BKPR        Priština Adem Jashari International Airport
# 16736  CN-0083                                     Guodu Air Base
# 17886     CYCD  Nanaimo International Air And Space Port / RCA...
# 17919     CYEG                     Edmonton International Airport
# 17974     CYHZ          Halifax / Stanfield International Airport
# 18015     CYLW                      Kelowna International Airport
# 18049     CYOW     Ottawa Macdonald-Cartier International Airport
# 18140     CYUL  Montreal / Pierre Elliott Trudeau Internationa...
# 18154     CYVR                    Vancouver International Airport
# 18159     CYWG  Winnipeg / James Armstrong Richardson Internat...
# 18183     CYXX                   Abbotsford International Airport
# 18184     CYXY    Whitehorse / Erik Nielsen International Airport
# 18187     CYYC                      Calgary International Airport
# 18193     CYYJ                     Victoria International Airport
# 18200     CYYT                   St. John's International Airport
# 18204     CYYZ            Lester B. Pearson International Airport
# 18207     CYZF                  Yellowknife International Airport
# 18483     DAAE                    Soummam – Abane Ramdane Airport
# 18485     DAAG                          Houari Boumediene Airport
# 19090     DFFD                                Ouagadougou Airport
# 19105     DGAA                       Kotoka International Airport
# 19197     DNAA               Nnamdi Azikiwe International Airport
# 19198     DNAI                    Akwa Ibom International Airport
# 19217     DNKN                 Mallam Aminu International Airport
# 19220     DNMM             Murtala Muhammed International Airport
# 19245     DRRN                 Diori Hamani International Airport
# 19266     DTTA               Tunis Carthage International Airport
# ...        ...                                                ...
# 63835     ZBYN                               Taiyuan Wusu Airport
# 63844     ZGGG             Guangzhou Baiyun International Airport
# 63845     ZGHA            Changsha Huanghua International Airport
# 63849     ZGKL            Guilin Liangjiang International Airport
# 63853     ZGNN                               Nanning Wuxu Airport
# 63858     ZGSZ              Shenzhen Bao'an International Airport
# 63864     ZHCC           Zhengzhou Xinzheng International Airport
# 63867     ZHHH                 Wuhan Tianhe International Airport
# 63878     ZJHK                Haikou Meilan International Airport
# 63880     ZJSY                Sanya Phoenix International Airport
# 63905     ZLXY               Xi'an Xianyang International Airport
# 63946     ZMCK   Ulaanbaatar Chinggis Khaan International Airport
# 63959     ZMUB                 Buyant-Ukhaa International Airport
# 63971     ZPPP            Kunming Changshui International Airport
# 63975     ZSAM                 Xiamen Gaoqi International Airport
# 63981     ZSFZ               Fuzhou Changle International Airport
# 63983     ZSHC            Hangzhou Xiaoshan International Airport
# 63986     ZSJN                                   Yaoqiang Airport
# 63992     ZSNB                 Ningbo Lishe International Airport
# 63993     ZSNJ                              Nanjing Lukou Airport
# 63995     ZSPD              Shanghai Pudong International Airport
# 64000     ZSSS            Shanghai Hongqiao International Airport
# 64008     ZSWZ              Wenzhou Longwan International Airport
# 64020     ZUCK           Chongqing Jiangbei International Airport
# 64025     ZUGY                                Longdongbao Airport
# 64045     ZUUU            Chengdu Shuangliu International Airport
# 64116     ZWWW                Ürümqi Diwopu International Airport
# 64127     ZYHB                                    Taiping Airport
# 64142     ZYTL            Dalian Zhoushuizi International Airport
# 64144     ZYTX             Shenyang Taoxian International Airport
#
#                  municipality
# 10621                 Honiara
# 12122            Port Moresby
# 12628               Reykjavík
# 12675               Prishtina
# 16736          Xintai, Tai'an
# 17886                 Nanaimo
# 17919                Edmonton
# 17974                 Halifax
# 18015                 Kelowna
# 18049                  Ottawa
# 18140                Montréal
# 18154               Vancouver
# 18159                Winnipeg
# 18183              Abbotsford
# 18184              Whitehorse
# 18187                 Calgary
# 18193                Victoria
# 18200              St. John's
# 18204                 Toronto
# 18207             Yellowknife
# 18483                  Béjaïa
# 18485                 Algiers
# 19090             Ouagadougou
# 19105                   Accra
# 19197                   Abuja
# 19198                     Uyo
# 19217                    Kano
# 19220                   Lagos
# 19245                  Niamey
# 19266                   Tunis
# ...                       ...
# 63835                 Taiyuan
# 63844        Huadu, Guangzhou
# 63845                Changsha
# 63849         Guilin (Lingui)
# 63853      Nanning (Jiangnan)
# 63858        Bao'an, Shenzhen
# 63864               Zhengzhou
# 63867                   Wuhan
# 63878         Haikou (Meilan)
# 63880          Sanya (Tianya)
# 63905                   Xi'an
# 63946  Ulaanbaatar (Sergelen)
# 63959             Ulaanbaatar
# 63971                 Kunming
# 63975                  Xiamen
# 63981                  Fuzhou
# 63983                Hangzhou
# 63986                   Jinan
# 63992                  Ningbo
# 63993                 Nanjing
# 63995                Shanghai
# 64000                Shanghai
# 64008                 Wenzhou
# 64020               Chongqing
# 64025                 Guiyang
# 64045                 Chengdu
# 64116                  Ürümqi
# 64127                  Harbin
# 64142       Ganjingzi, Dalian
# 64144        Hunnan, Shenyang
#
# [654 rows x 3 columns]

# %% [markdown]
# ### ORDER BY
# По умолчанию Pandas сортирует данные по возрастанию. Для обратной сортировки используйте выражение ascending=False.

# %%
airport_freq[airport_freq.airport_ident == 'KLAX'].sort_values('type')    #order by asc
# Out:
#           id  airport_ref airport_ident  type description  frequency_mhz
# 11958  60767         3632          KLAX   APP   SOCAL APP          36.07
# 11959  60766         3632          KLAX   APP   SOCAL APP         124.30
# 11960  60768         3632          KLAX  ATIS        ATIS         133.80
# 11961  60769         3632          KLAX   CLD    CLNC DEL         121.40
# 11962  60770         3632          KLAX   DEP   SOCAL DEP         124.30
# 11963  60771         3632          KLAX   GND         GND         121.65
# 11964  60772         3632          KLAX  MISC          CG          34.50
# 11965  60773         3632          KLAX  MISC          CG         898.40
# 11966  60774         3632          KLAX   OPS          AF          37.22
# 11967  60775         3632          KLAX   TWR         TWR         119.80
# 11968  60776         3632          KLAX  UNIC      UNICOM         122.95

# %%
# order by desc
airport_freq[airport_freq.airport_ident == 'KLAX'].sort_values('frequency_mhz', ascending=False)
# Out:
#           id  airport_ref airport_ident  type description  frequency_mhz
# 11965  60773         3632          KLAX  MISC          CG         898.40
# 11960  60768         3632          KLAX  ATIS        ATIS         133.80
# 11959  60766         3632          KLAX   APP   SOCAL APP         124.30
# 11962  60770         3632          KLAX   DEP   SOCAL DEP         124.30
# 11968  60776         3632          KLAX  UNIC      UNICOM         122.95
# 11963  60771         3632          KLAX   GND         GND         121.65
# 11961  60769         3632          KLAX   CLD    CLNC DEL         121.40
# 11967  60775         3632          KLAX   TWR         TWR         119.80
# 11966  60774         3632          KLAX   OPS          AF          37.22
# 11958  60767         3632          KLAX   APP   SOCAL APP          36.07
# 11964  60772         3632          KLAX  MISC          CG          34.50

# %%
airports[airports.type.isin(['heliport', 'balloonport'])]   # SQL-аналог IN
# Out:
#            id    ident      type  \
# 0        6523      00A  heliport
# 9      322658     00CN  heliport
# 12       6532     00FD  heliport
# 15       6535     00GE  heliport
# 16       6536     00HI  heliport
# 21       6540     00IN  heliport
# 25      45437     00LA  heliport
# 26       6544     00LL  heliport
# 29       6547     00MI  heliport
# 32     324642     00MT  heliport
# 35       6553     00NJ  heliport
# 39       6556     00OI  heliport
# 41       6557     00OR  heliport
# 42       6558     00PA  heliport
# 49       6563     00TE  heliport
# 61     322300     00WY  heliport
# 64       6577     01AK  heliport
# 66       6579     01AR  heliport
# 67       6580     01AZ  heliport
# 69       6582     01CA  heliport
# 71       6584     01CN  heliport
# 72       6585     01CO  heliport
# 73       6586     01CT  heliport
# 75       6588     01FD  heliport
# 77       6590     01GA  heliport
# 82       6594     01IL  heliport
# 83       6595     01IN  heliport
# 88       6600     01KY  heliport
# 92       6604     01MA  heliport
# 95       6607     01MI  heliport
# ...       ...      ...       ...
# 63693  312611  ZA-0117  heliport
# 63695  312624  ZA-0119  heliport
# 63716  318475  ZA-0140  heliport
# 63743  340248  ZA-0167  heliport
# 63744  340249  ZA-0168  heliport
# 63746  340250  ZA-0170  heliport
# 63747  340251  ZA-0171  heliport
# 63748  340252  ZA-0172  heliport
# 63749  340253  ZA-0173  heliport
# 63750  340254  ZA-0174  heliport
# 63751  340255  ZA-0175  heliport
# 63769  340274  ZA-0193  heliport
# 63776  340419  ZA-0200  heliport
# 63777  342032  ZA-0201  heliport
# 63778  342033  ZA-0202  heliport
# 63779  342034  ZA-0203  heliport
# 63781  342036  ZA-0205  heliport
# 63782  342037  ZA-0206  heliport
# 63783  342038  ZA-0207  heliport
# 63784  342039  ZA-0208  heliport
# 63785  342040  ZA-0209  heliport
# 63786  342041  ZA-0210  heliport
# 63787  342042  ZA-0211  heliport
# 63788  342043  ZA-0212  heliport
# 63789  342044  ZA-0213  heliport
# 63790  342045  ZA-0214  heliport
# 63791  342046  ZA-0215  heliport
# 63854  339169     ZGNT  heliport
# 63877  301278      ZIZ  heliport
# 64149   46378  ZZ-0001  heliport
#
#                                                     name  latitude_deg  \
# 0                                      Total Rf Heliport     40.070801
# 9                        Kitchen Creek Helibase Heliport     32.727374
# 12                                    Ringhaver Heliport     28.846600
# 15                                      Caffrey Heliport     33.889245
# 16                                    Kaupulehu Heliport     19.832715
# 21                       St Mary Medical Center Heliport     41.511398
# 25                     Shell Chemical East Site Heliport     30.191944
# 26                            Ac & R Components Heliport     39.665298
# 29                                 Dow Chemical Heliport     43.949402
# 32                        Livingston Healthcare Heliport     45.675000
# 35                           Colgate-Piscataway Heliport     40.520901
# 39                        Miami Valley Hospital Heliport     39.745300
# 41                                Steel Systems Heliport     44.932899
# 42                                        R J D Heliport     39.948898
# 49                        Tcjc-Northeast Campus Heliport     32.847599
# 61              Mountain View Regional Hospital Heliport     42.840361
# 64             Providence Seward Medical Center Heliport     60.105874
# 66               Community Hospital of De Queen Heliport     34.047298
# 67                                          Yat Heliport     34.608101
# 69                              Lugo Substation Heliport     34.368241
# 71      Los Angeles County Sheriff's Department Heliport     34.037800
# 72                  St Vincent General Hospital Heliport     39.245300
# 73                           Berlin Fairgrounds Heliport     41.627300
# 75              Advent Health Altamonte Springs Heliport     28.666639
# 77                               Medical Center Heliport     32.479301
# 82        Hoopeston Community Memorial Hospital Heliport     40.458599
# 83                           Community Hospital Heliport     40.130901
# 88                             Lourdes Hospital Heliport     37.051701
# 92                               Compaq Andover Heliport     42.625099
# 95                        Flow Through Terminal Heliport     43.049500
# ...                                                  ...           ...
# 63693                                      Pumba Helipad    -33.387799
# 63695                                 Cape Town Heliport    -33.901018
# 63716                          Kuruman Hospital Heliport    -27.459904
# 63743                  Netcare uMhlanga Hospital Helipad    -29.727510
# 63744                         Intertherm Durban Heliport    -29.749680
# 63746                     King Dinizulu Hospital Helipad    -29.821980
# 63747                    Life Westville Hospital Helipad    -29.850980
# 63748                     Life Entabeni Hospital Helipad    -29.855510
# 63749     Inkosi Albert Luthuli Central Hospital Helipad    -29.873860
# 63750                  King Edward VIII Hospital Helipad    -29.882200
# 63751                         Wentworth Hospital Helipad    -29.932900
# 63769                             Robben Island Heliport    -33.803255
# 63776                   Marion Research Station Heliport    -46.875999
# 63777                                  Ultimate Heliport    -26.028400
# 63778                          Edenvale Hospital Helipad    -26.128400
# 63779                        Mediclinic Sandton Heliport    -26.077900
# 63781                                      Sanan Helipad    -26.229800
# 63782  Charlotte Maxeke Johannesburg Academic Hospita...    -26.175900
# 63783                    Waterfall City Hospital Helipad    -26.013500
# 63784                           Milpark Hospital Helipad    -26.180600
# 63785                       Sunninghill Hospital Helipad    -26.038500
# 63786                                  Midstream Helipad    -25.927900
# 63787                           Olivedale Clinic Helipad    -26.055300
# 63788                             Dimension Data Helipad    -26.042200
# 63789                     Life Fourways Hospital Helipad    -26.011900
# 63790                      Mediclinic Midstream Heliport    -25.924800
# 63791                                    Benoni Heliport    -26.173800
# 63854                           Shenzhen Nantou Heliport     22.558736
# 63877                                   Zamzama Heliport     26.710944
# 64149                                    Sealand Helipad     51.894444
#
#        longitude_deg  elevation_ft continent iso_country iso_region  \
# 0         -74.933601          11.0       NaN          US      US-PA
# 9        -116.459742        3350.0       NaN          US      US-CA
# 12        -82.345398          25.0       NaN          US      US-FL
# 15        -84.737930         957.0       NaN          US      US-GA
# 16       -155.980233          43.0       NaN          US      US-HI
# 21        -87.260597         634.0       NaN          US      US-IN
# 25        -90.980833          15.0       NaN          US      US-LA
# 26        -89.705597         600.0       NaN          US      US-IL
# 29        -86.416702         588.0       NaN          US      US-MI
# 32       -110.525150        4465.0       NaN          US      US-MT
# 35        -74.474602          78.0       NaN          US      US-NJ
# 39        -84.187401         905.0       NaN          US      US-OH
# 41       -123.129997         195.0       NaN          US      US-OR
# 42        -75.746902         402.0       NaN          US      US-PA
# 49        -97.189499         600.0       NaN          US      US-TX
# 61       -106.224443        5210.0       NaN          US      US-WY
# 64       -149.446249         120.0       NaN          US      US-AK
# 66        -94.354897         400.0       NaN          US      US-AR
# 67       -111.864998        3300.0       NaN          US      US-AZ
# 69       -117.370059        3733.0       NaN          US      US-CA
# 71       -118.153999         300.0       NaN          US      US-CA
# 72       -106.246002       10175.0       NaN          US      US-CO
# 73        -72.727501          60.0       NaN          US      US-CT
# 75        -81.369700          86.0       NaN          US      US-FL
# 77        -84.979103         319.0       NaN          US      US-GA
# 82        -87.659500         583.0       NaN          US      US-IL
# 83        -85.695801         890.0       NaN          US      US-IN
# 88        -88.646896         419.0       NaN          US      US-KY
# 92        -71.180099         140.0       NaN          US      US-MA
# 95        -83.679703         736.0       NaN          US      US-MI
# ...              ...           ...       ...         ...        ...
# 63693      26.410595           NaN        AF          ZA      ZA-EC
# 63695      18.425936           NaN        AF          ZA      ZA-WC
# 63716      23.443762           NaN        AF          ZA      ZA-NC
# 63743      31.068680           NaN        AF          ZA      ZA-NL
# 63744      31.029460           NaN        AF          ZA      ZA-NL
# 63746      30.989050           NaN        AF          ZA      ZA-NL
# 63747      30.932110           NaN        AF          ZA      ZA-NL
# 63748      30.987430           NaN        AF          ZA      ZA-NL
# 63749      30.958760           NaN        AF          ZA      ZA-NL
# 63750      30.989530           NaN        AF          ZA      ZA-NL
# 63751      30.989150           NaN        AF          ZA      ZA-NL
# 63769      18.366981           NaN        AF          ZA      ZA-WC
# 63776      37.857356           NaN        AF          ZA      ZA-WC
# 63777      28.110800        4826.0        AF          ZA      ZA-GT
# 63778      28.128800        5191.0        AF          ZA      ZA-GT
# 63779      28.012100        5134.0        AF          ZA      ZA-GT
# 63781      28.041000        5597.0        AF          ZA      ZA-GT
# 63782      28.044100        5817.0        AF          ZA      ZA-GT
# 63783      28.102200        4888.0        AF          ZA      ZA-GT
# 63784      28.017000        5486.0        AF          ZA      ZA-GT
# 63785      28.070000        4787.0        AF          ZA      ZA-GT
# 63786      28.197100        4954.0        AF          ZA      ZA-GT
# 63787      27.971800        4904.0        AF          ZA      ZA-GT
# 63788      28.024800        4993.0        AF          ZA      ZA-GT
# 63789      27.995200        4813.0        AF          ZA      ZA-GT
# 63790      28.182700        5128.0        AF          ZA      ZA-GT
# 63791      28.349200        5377.0        AF          ZA      ZA-GT
# 63854     113.925612           NaN        AS          CN      CN-44
# 63877      67.667250         128.0        AS          PK      PK-SD
# 64149       1.482500          40.0        EU          GB     GB-ENG
#
#                     municipality scheduled_service gps_code iata_code  \
# 0                       Bensalem                no      00A       NaN
# 9                    Pine Valley                no     00CN       NaN
# 12                     Riverview                no     00FD       NaN
# 15                         Hiram                no     00GE       NaN
# 16                   Kailua-Kona                no     00HI       NaN
# 21                        Hobart                no     00IN       NaN
# 25                      Gonzales                no     00LA       NaN
# 26                       Chatham                no     00LL       NaN
# 29                     Ludington                no     00MI       NaN
# 32                    Livingston                no     00MT       NaN
# 35                 New Brunswick                no     00NJ       NaN
# 39                        Dayton                no     00OI       NaN
# 41                         Salem                no     00OR       NaN
# 42                   Coatesville                no     00PA       NaN
# 49                    Fort Worth                no     00TE       NaN
# 61                        Casper                no     00WY       NaN
# 64                        Seward                no     01AK       NaN
# 66                      De Queen                no     01AR       NaN
# 67                    Camp Verde                no     01AZ       NaN
# 69                      Hesperia                no     01CA       NaN
# 71                   Los Angeles                no     01CN       NaN
# 72                     Leadville                no     01CO       NaN
# 73                        Berlin                no     01CT       NaN
# 75             Altamonte Springs                no     01FD       NaN
# 77                      Columbus                no     01GA       NaN
# 82                     Hoopeston                no     01IL       NaN
# 83                      Anderson                no     01IN       NaN
# 88                       Paducah                no     01KY       NaN
# 92                       Andover                no     01MA       NaN
# 95                         Flint                no     01MI       NaN
# ...                          ...               ...      ...       ...
# 63693         Nelson Mandela Bay                no      NaN       NaN
# 63695                        NaN                no      NaN       NaN
# 63716                    Kuruman                no      NaN       NaN
# 63743                   uMhlanga                no      NaN       NaN
# 63744               Durban North                no      NaN       NaN
# 63746                     Durban                no      NaN       NaN
# 63747                  Westville                no      NaN       NaN
# 63748                     Durban                no      NaN       NaN
# 63749                     Durban                no      NaN       NaN
# 63750                     Durban                no      NaN       NaN
# 63751                      Bluff                no      NaN       NaN
# 63769                  Cape Town                no      NaN       NaN
# 63776  Cape Town (Marion Island)                no      NaN       NaN
# 63777                    Midrand                no      NaN       NaN
# 63778               Johannesburg                no      NaN       NaN
# 63779               Johannesburg                no      NaN       NaN
# 63781               Johannesburg                no      NaN       NaN
# 63782               Johannesburg                no      NaN       NaN
# 63783                    Midrand                no      NaN       NaN
# 63784               Johannesburg                no      NaN       NaN
# 63785                    Sandton                no      NaN       NaN
# 63786            Olifantsfontein                no      NaN       NaN
# 63787                   Randburg                no      NaN       NaN
# 63788                    Sandton                no      NaN       NaN
# 63789                    Sandton                no      NaN       NaN
# 63790            Olifantsfontein                no      NaN       NaN
# 63791                     Benoni                no      NaN       NaN
# 63854          Nanshan, Shenzhen                no     ZGNT       NaN
# 63877          Zamzama Gas Field                no      NaN       ZIZ
# 64149                    Sealand                no      NaN       NaN
#
#       local_code                                    home_link  \
# 0            00A                                          NaN
# 9           00CN                                          NaN
# 12          00FD                                          NaN
# 15          00GE                                          NaN
# 16          00HI                                          NaN
# 21          00IN                                          NaN
# 25          00LA                                          NaN
# 26          00LL                                          NaN
# 29          00MI                                          NaN
# 32          00MT                                          NaN
# 35          00NJ                                          NaN
# 39          00OI                                          NaN
# 41          00OR                                          NaN
# 42          00PA                                          NaN
# 49          00TE                                          NaN
# 61          00WY                                          NaN
# 64          01AK                                          NaN
# 66          01AR                                          NaN
# 67          01AZ                                          NaN
# 69          01CA                                          NaN
# 71          01CN                                          NaN
# 72          01CO                                          NaN
# 73          01CT                                          NaN
# 75          01FD                                          NaN
# 77          01GA                                          NaN
# 82          01IL                                          NaN
# 83          01IN                                          NaN
# 88          01KY                                          NaN
# 92          01MA                                          NaN
# 95          01MI                                          NaN
# ...          ...                                          ...
# 63693        NaN  http://www.pumbagamereserve.co.za/amenities
# 63695        NaN                                          NaN
# 63716        NaN                                          NaN
# 63743        NaN                                          NaN
# 63744        NaN                                          NaN
# 63746        NaN                                          NaN
# 63747        NaN                                          NaN
# 63748        NaN                                          NaN
# 63749        NaN                                          NaN
# 63750        NaN                                          NaN
# 63751        NaN                                          NaN
# 63769        NaN                                          NaN
# 63776        NaN                                          NaN
# 63777        NaN                                          NaN
# 63778        NaN                                          NaN
# 63779        NaN                                          NaN
# 63781        NaN                                          NaN
# 63782        NaN                                          NaN
# 63783        NaN                                          NaN
# 63784        NaN                                          NaN
# 63785        NaN                                          NaN
# 63786        NaN                                          NaN
# 63787        NaN                                          NaN
# 63788        NaN                                          NaN
# 63789        NaN                                          NaN
# 63790        NaN                                          NaN
# 63791        NaN                                          NaN
# 63854        NaN                                          NaN
# 63877        NaN                                          NaN
# 64149        NaN                   http://www.sealandgov.org/
#
#                                           wikipedia_link  \
# 0                                                    NaN
# 9                                                    NaN
# 12                                                   NaN
# 15                                                   NaN
# 16                                                   NaN
# 21                                                   NaN
# 25                                                   NaN
# 26                                                   NaN
# 29                                                   NaN
# 32                                                   NaN
# 35                                                   NaN
# 39                                                   NaN
# 41                                                   NaN
# 42                                                   NaN
# 49                                                   NaN
# 61                                                   NaN
# 64                                                   NaN
# 66                                                   NaN
# 67                                                   NaN
# 69                                                   NaN
# 71                                                   NaN
# 72                                                   NaN
# 73                                                   NaN
# 75                                                   NaN
# 77                                                   NaN
# 82                                                   NaN
# 83                                                   NaN
# 88                                                   NaN
# 92                                                   NaN
# 95                                                   NaN
# ...                                                  ...
# 63693                                                NaN
# 63695                                                NaN
# 63716                                                NaN
# 63743                                                NaN
# 63744                                                NaN
# 63746                                                NaN
# 63747                                                NaN
# 63748                                                NaN
# 63749                                                NaN
# 63750                                                NaN
# 63751                                                NaN
# 63769                                                NaN
# 63776                                                NaN
# 63777                                                NaN
# 63778                                                NaN
# 63779                                                NaN
# 63781                                                NaN
# 63782                                                NaN
# 63783                                                NaN
# 63784                                                NaN
# 63785                                                NaN
# 63786                                                NaN
# 63787                                                NaN
# 63788                                                NaN
# 63789                                                NaN
# 63790                                                NaN
# 63791                                                NaN
# 63854                                                NaN
# 63877                                                NaN
# 64149  https://en.wikipedia.org/wiki/Principality_of_...
#
#                          keywords
# 0                             NaN
# 9                             NaN
# 12                            NaN
# 15                            NaN
# 16                            NaN
# 21                            NaN
# 25                            NaN
# 26                            NaN
# 29                            NaN
# 32                            NaN
# 35                            NaN
# 39                            NaN
# 41                            NaN
# 42                            NaN
# 49                            NaN
# 61                            NaN
# 64                            NaN
# 66                            NaN
# 67                            NaN
# 69                            NaN
# 71                            NaN
# 72                            NaN
# 73                            NaN
# 75     Florida Hospital-Altamonte
# 77                            NaN
# 82                            NaN
# 83                            NaN
# 88                            NaN
# 92                            NaN
# 95                            NaN
# ...                           ...
# 63693                         NaN
# 63695                         NaN
# 63716                         NaN
# 63743                         NaN
# 63744                         NaN
# 63746                         NaN
# 63747                         NaN
# 63748                         NaN
# 63749                         NaN
# 63750                         NaN
# 63751                         NaN
# 63769                         NaN
# 63776                         NaN
# 63777                         NaN
# 63778                         NaN
# 63779                         NaN
# 63781                         NaN
# 63782                         NaN
# 63783                         NaN
# 63784                         NaN
# 63785                         NaN
# 63786                         NaN
# 63787                         NaN
# 63788                         NaN
# 63789                         NaN
# 63790                         NaN
# 63791                         NaN
# 63854                         NaN
# 63877                         NaN
# 64149        Roughs Tower Helipad
#
# [15057 rows x 18 columns]

# %%
airports[~airports.type.isin(['heliport', 'balloonport'])]   # SQL-аналог NOT IN
# Out:
#            id    ident            type  \
# 1      323361     00AA   small_airport
# 2        6524     00AK   small_airport
# 3        6525     00AL   small_airport
# 4        6526     00AR          closed
# 5      322127     00AS   small_airport
# 6        6527     00AZ   small_airport
# 7        6528     00CA   small_airport
# 8      324424     00CL   small_airport
# 10       6529     00CO          closed
# 11       6531     00FA   small_airport
# 13       6533     00FL   small_airport
# 14       6534     00GA   small_airport
# 17       6537     00ID   small_airport
# 18     322581     00IG   small_airport
# 19       6538     00II          closed
# 20       6539     00IL   small_airport
# 22       6541     00IS   small_airport
# 23       6542     00KS   small_airport
# 24       6543     00KY   small_airport
# 27       6545     00LS   small_airport
# 28       6546     00MD   small_airport
# 30       6548     00MN   small_airport
# 31       6549     00MO   small_airport
# 33       6551      00N   small_airport
# 34       6552     00NC   small_airport
# 36     321919     00NK   seaplane_base
# 37       6554     00NY   small_airport
# 38       6555     00OH          closed
# 40     328503     00OK   small_airport
# 43      45773     00PN   small_airport
# ...       ...      ...             ...
# 64122   30827     ZYCY  medium_airport
# 64123  327349     ZYDU  medium_airport
# 64124  324338     ZYFX   small_airport
# 64125  313994     ZYFY  medium_airport
# 64126  335271     ZYGH   small_airport
# 64127   27238     ZYHB   large_airport
# 64128   31576     ZYHE  medium_airport
# 64129   31701     ZYJL   small_airport
# 64130   27239     ZYJM  medium_airport
# 64131  327450     ZYJS  medium_airport
# 64132  313337     ZYJX  medium_airport
# 64133   31706     ZYJZ   small_airport
# 64134  307012     ZYLD  medium_airport
# 64135  300516     ZYLS  medium_airport
# 64136  335272     ZYLY   small_airport
# 64137   27240     ZYMD  medium_airport
# 64138  301193     ZYMH  medium_airport
# 64139   27241     ZYQQ  medium_airport
# 64140  327451     ZYSQ  medium_airport
# 64141  307017     ZYTH   small_airport
# 64142   27242     ZYTL   large_airport
# 64143  307013     ZYTN  medium_airport
# 64144   27243     ZYTX   large_airport
# 64145  342103     ZYXW          closed
# 64146   27244     ZYYJ  medium_airport
# 64147  317861     ZYYK  medium_airport
# 64148   32753     ZYYY  medium_airport
# 64150  307326  ZZ-0002   small_airport
# 64151  342102     ZZZW          closed
# 64152  313629     ZZZZ   small_airport
#
#                                            name  latitude_deg  longitude_deg  \
# 1                          Aero B Ranch Airport     38.704022    -101.473911
# 2                                  Lowell Field     59.949200    -151.695999
# 3                                  Epps Airpark     34.864799     -86.770302
# 4            Newport Hospital & Clinic Heliport     35.608700     -91.254898
# 5                                Fulton Airport     34.942803     -97.818019
# 6                                Cordes Airport     34.305599    -112.165001
# 7                       Goldstone (GTS) Airport     35.354740    -116.885329
# 8                           Williams Ag Airport     39.427188    -121.763427
# 10                                   Cass Field     40.622202    -104.344002
# 11                          Grass Patch Airport     28.645500     -82.219002
# 13                            River Oak Airport     27.230900     -80.969200
# 14                             Lt World Airport     33.767502     -84.068298
# 17                         Delta Shores Airport     48.145302    -116.213997
# 18                                Goltl Airport     39.724028    -101.395994
# 19           Bailey Generation Station Heliport     41.644501     -87.122803
# 20                               Hammer Airport     41.978401     -89.560402
# 22            Hayenga's Cant Find Farms Airport     40.025600     -89.122902
# 23                          Hayden Farm Airport     38.727798     -94.930496
# 24                        Robbins Roost Airport     37.409401     -84.619698
# 27                              Lejeune Airport     30.136299     -92.429398
# 28                                 Slater Field     38.757099     -75.753799
# 30                Battle Lake Municipal Airport     46.299999     -95.700302
# 31                Cooper Flying Service Airport     37.202801     -94.412399
# 33                                Bucks Airport     39.473202     -75.185204
# 34                        North Raleigh Airport     36.085201     -78.371399
# 36                    Cliche Cove Seaplane Base     44.811861     -73.369806
# 37                               Weiss Airfield     42.900101     -77.499702
# 38                               Exit 3 Airport     41.590476     -84.141583
# 40                     Gull Bay Landing Airport     36.198598     -96.217693
# 43                                Ferrell Field     41.299500     -80.211111
# ...                                         ...           ...            ...
# 64122                          Chaoyang Airport     41.538101     120.434998
# 64123                  Wudalianchi Dedu Airport     48.445000     126.133000
# 64124                             Fuxin Airport     42.069014     121.718122
# 64125                             Dongji Aiport     48.199494     134.366447
# 64126                             Genhe Airport     50.700277     121.382500
# 64127                           Taiping Airport     45.623402     126.250000
# 64128                       Heihe Aihui Airport     50.171621     127.308884
# 64129                             Jilin Airport     44.002201     126.396004
# 64130                           Jiamusi Airport     46.843399     130.464996
# 64131                      Jiansanjiang Airport     47.110000     132.660278
# 64132                    Jixi Xingkaihu Airport     45.293000     131.193000
# 64133               Jinzhou Xiaolingzi Air Base     41.101398     121.061996
# 64134                             Lindu Airport     47.752056     129.019125
# 64135                      Yushu Batang Airport     32.836389      97.036389
# 64136                          Liaoyang Airbase     41.277976     123.078729
# 64137  Mudanjiang Hailang International Airport     44.524101     129.569000
# 64138                           Gu-Lian Airport     52.912778     122.430000
# 64139                  Qiqihar Sanjiazi Airport     47.239601     123.917999
# 64140                 Songyuan Chaganhu Airport     44.938114     124.550178
# 64141                              Tahe Airport     52.224444     124.720222
# 64142   Dalian Zhoushuizi International Airport     38.965698     121.539001
# 64143                 Tonghua Sanyuanpu Airport     42.253889     125.703333
# 64144    Shenyang Taoxian International Airport     41.639801     123.483002
# 64145                         Mt Logan Airstrip     60.792990    -138.694027
# 64146               Yanji Chaoyangchuan Airport     42.882801     129.451004
# 64147                     Yingkou Lanqi Airport     40.542524     122.358600
# 64148                   Shenyang Dongta Airport     41.784401     123.496002
# 64150                 Glorioso Islands Airstrip    -11.584278      47.296389
# 64151                    Scandium City Heliport     69.355287    -138.939310
# 64152                    Satsuma Iōjima Airport     30.784722     130.270556
#
#        elevation_ft continent iso_country iso_region  \
# 1            3435.0       NaN          US      US-KS
# 2             450.0       NaN          US      US-AK
# 3             820.0       NaN          US      US-AL
# 4             237.0       NaN          US      US-AR
# 5            1100.0       NaN          US      US-OK
# 6            3810.0       NaN          US      US-AZ
# 7            3038.0       NaN          US      US-CA
# 8              87.0       NaN          US      US-CA
# 10           4830.0       NaN          US      US-CO
# 11             53.0       NaN          US      US-FL
# 13             35.0       NaN          US      US-FL
# 14            700.0       NaN          US      US-GA
# 17           2064.0       NaN          US      US-ID
# 18           3359.0       NaN          US      US-KS
# 19            600.0       NaN          US      US-IN
# 20            840.0       NaN          US      US-IL
# 22            820.0       NaN          US      US-IL
# 23           1100.0       NaN          US      US-KS
# 24           1265.0       NaN          US      US-KY
# 27             12.0       NaN          US      US-LA
# 28             45.0       NaN          US      US-MD
# 30           1365.0       NaN          US      US-MN
# 31            970.0       NaN          US      US-MO
# 33            105.0       NaN          US      US-NJ
# 34            348.0       NaN          US      US-NC
# 36             96.0       NaN          US      US-NY
# 37           1000.0       NaN          US      US-NY
# 38            785.0       NaN          US      US-OH
# 40            960.0       NaN          US      US-OK
# 43           1301.0       NaN          US      US-PA
# ...             ...       ...         ...        ...
# 64122         568.0        AS          CN      CN-21
# 64123         984.0        AS          CN      CN-23
# 64124         548.0        AS          CN      CN-21
# 64125           NaN        AS          CN      CN-23
# 64126        2257.0        AS          CN      CN-15
# 64127         457.0        AS          CN      CN-23
# 64128        1047.0        AS          CN      CN-23
# 64129           NaN        AS          CN      CN-22
# 64130         262.0        AS          CN      CN-23
# 64131           NaN        AS          CN      CN-23
# 64132         760.0        AS          CN      CN-23
# 64133           NaN        AS          CN      CN-21
# 64134         791.0        AS          CN      CN-23
# 64135       12816.0        AS          CN      CN-63
# 64136          57.0        AS          CN      CN-21
# 64137         883.0        AS          CN      CN-23
# 64138        1836.0        AS          CN      CN-23
# 64139         477.0        AS          CN      CN-23
# 64140         459.0        AS          CN      CN-22
# 64141        1240.0        AS          CN      CN-23
# 64142         107.0        AS          CN      CN-21
# 64143        1200.0        AS          CN      CN-22
# 64144         198.0        AS          CN      CN-21
# 64145        1997.0       NaN          CA      CA-YT
# 64146         624.0        AS          CN      CN-22
# 64147           NaN        AS          CN      CN-21
# 64148           NaN        AS          CN      CN-21
# 64150          11.0        AF          TF     TF-U-A
# 64151           4.0       NaN          CA      CA-YT
# 64152         338.0        AS          JP      JP-46
#
#                                municipality scheduled_service gps_code  \
# 1                                     Leoti                no     00AA
# 2                              Anchor Point                no     00AK
# 3                                   Harvest                no     00AL
# 4                                   Newport                no      NaN
# 5                                      Alex                no     00AS
# 6                                    Cordes                no     00AZ
# 7                                   Barstow                no     00CA
# 8                                     Biggs                no     00CL
# 10                               Briggsdale                no      NaN
# 11                                 Bushnell                no     00FA
# 13                               Okeechobee                no     00FL
# 14                                 Lithonia                no     00GA
# 17                               Clark Fork                no     00ID
# 18                                 McDonald                no     00IG
# 19                               Chesterton                no      NaN
# 20                                     Polo                no     00IL
# 22                                    Kings                no     00IS
# 23                                  Gardner                no     00KS
# 24                                 Stanford                no     00KY
# 27                                Esterwood                no     00LS
# 28                             Federalsburg                no     00MD
# 30                              Battle Lake                no     00MN
# 31                                     Alba                no     00MO
# 33                                Bridgeton                no      00N
# 34                                Louisburg                no     00NC
# 36                              Beekmantown                no     00NK
# 37                          West Bloomfield                no     00NY
# 38                                  Wauseon                no      NaN
# 40                              Sandsprings                no     00OK
# 43                                   Mercer                no     00PN
# ...                                     ...               ...      ...
# 64122                    Shuangta, Chaoyang               yes     ZYCY
# 64123                           Wudalianchi               yes     ZYDU
# 64124                           Xihe, Fuxin                no     ZYFX
# 64125                                Fuyuan               yes     ZYFY
# 64126                              Haolibao                no     ZYGH
# 64127                                Harbin               yes     ZYHB
# 64128                          Aihui, Heihe               yes     ZYHE
# 64129                                 Jilin                no     ZYJL
# 64130                               Jiamusi               yes     ZYJM
# 64131                          Jiansanjiang               yes     ZYJS
# 64132                                  Jixi               yes     ZYJX
# 64133                        Taihe, Jinzhou               yes      NaN
# 64134                                Yichun               yes     ZYLD
# 64135                                 Yushu                no     ZYLS
# 64136                     Taizihe, Liaoyang                no     ZYLY
# 64137                            Mudanjiang               yes     ZYMD
# 64138                                  Mohe               yes     ZYMH
# 64139                               Qiqihar               yes     ZYQQ
# 64140  Qian Gorlos Mongol Autonomous County               yes     ZYSQ
# 64141                                  Tahe                no     ZYTH
# 64142                     Ganjingzi, Dalian               yes     ZYTL
# 64143                               Tonghua               yes     ZYTN
# 64144                      Hunnan, Shenyang               yes     ZYTX
# 64145                     Unorganized Yukon                no     ZYXW
# 64146                                 Yanji               yes     ZYYJ
# 64147                      Laobian, Yingkou               yes     ZYYK
# 64148                      Dadong, Shenyang                no     ZYYY
# 64150                      Grande Glorieuse                no      NaN
# 64151                   (Old) Scandium City                no     ZZZW
# 64152                          Mishima-Mura                no     RJX7
#
#       iata_code local_code home_link  \
# 1           NaN       00AA       NaN
# 2           NaN       00AK       NaN
# 3           NaN       00AL       NaN
# 4           NaN        NaN       NaN
# 5           NaN       00AS       NaN
# 6           NaN       00AZ       NaN
# 7           NaN       00CA       NaN
# 8           NaN       00CL       NaN
# 10          NaN        NaN       NaN
# 11          NaN       00FA       NaN
# 13          NaN       00FL       NaN
# 14          NaN       00GA       NaN
# 17          NaN       00ID       NaN
# 18          NaN       00IG       NaN
# 19          NaN        NaN       NaN
# 20          NaN       00IL       NaN
# 22          NaN       00IS       NaN
# 23          NaN       00KS       NaN
# 24          NaN       00KY       NaN
# 27          NaN       00LS       NaN
# 28          NaN       00MD       NaN
# 30          NaN       00MN       NaN
# 31          NaN       00MO       NaN
# 33          NaN        00N       NaN
# 34          NaN       00NC       NaN
# 36          NaN       00NK       NaN
# 37          NaN       00NY       NaN
# 38          NaN        NaN       NaN
# 40          NaN       00OK       NaN
# 43          NaN       00PN       NaN
# ...         ...        ...       ...
# 64122       CHG        NaN       NaN
# 64123       DTU        NaN       NaN
# 64124       NaN        NaN       NaN
# 64125       FYJ        NaN       NaN
# 64126       NaN        NaN       NaN
# 64127       HRB        NaN       NaN
# 64128       HEK        NaN       NaN
# 64129       JIL        NaN       NaN
# 64130       JMU        NaN       NaN
# 64131       JSJ        NaN       NaN
# 64132       JXA        NaN       NaN
# 64133       NaN        NaN       NaN
# 64134       LDS        NaN       NaN
# 64135       YUS        NaN       NaN
# 64136       NaN        NaN       NaN
# 64137       MDG        NaN       NaN
# 64138       OHE        NaN       NaN
# 64139       NDG        NaN       NaN
# 64140       YSQ        NaN       NaN
# 64141       NaN        NaN       NaN
# 64142       DLC        NaN       NaN
# 64143       TNH        NaN       NaN
# 64144       SHE        NaN       NaN
# 64145       ZYA       YK90       NaN
# 64146       YNJ        NaN       NaN
# 64147       YKH        NaN       NaN
# 64148       NaN        NaN       NaN
# 64150       NaN        NaN       NaN
# 64151       ZYW       YK96       NaN
# 64152       NaN       RJX7       NaN
#
#                                           wikipedia_link  \
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# 5                                                    NaN
# 6                                                    NaN
# 7                                                    NaN
# 8                                                    NaN
# 10                                                   NaN
# 11                                                   NaN
# 13                                                   NaN
# 14                                                   NaN
# 17                                                   NaN
# 18                                                   NaN
# 19                                                   NaN
# 20                                                   NaN
# 22                                                   NaN
# 23                                                   NaN
# 24                                                   NaN
# 27                                                   NaN
# 28                                                   NaN
# 30                                                   NaN
# 31                                                   NaN
# 33                                                   NaN
# 34                                                   NaN
# 36                                                   NaN
# 37                                                   NaN
# 38                                                   NaN
# 40                                                   NaN
# 43                                                   NaN
# ...                                                  ...
# 64122     https://en.wikipedia.org/wiki/Chaoyang_Airport
# 64123  https://en.wikipedia.org/wiki/Wudalianchi_Dedu...
# 64124                                                NaN
# 64125  https://en.wikipedia.org/wiki/Fuyuan_Dongji_Ai...
# 64126                                                NaN
# 64127  https://en.wikipedia.org/wiki/Harbin_Taiping_I...
# 64128  https://en.wikipedia.org/wiki/Heihe_Aihui_Airport
# 64129  https://en.wikipedia.org/wiki/Jilin_Ertaizi_Ai...
# 64130      https://en.wikipedia.org/wiki/Jiamusi_Airport
# 64131  https://en.wikipedia.org/wiki/Jiansanjiang_Air...
# 64132  https://en.wikipedia.org/wiki/Jixi_Xingkaihu_A...
# 64133  https://en.wikipedia.org/wiki/Jinzhou_Xiaoling...
# 64134  https://en.wikipedia.org/wiki/Yichun_Lindu_Air...
# 64135  https://en.wikipedia.org/wiki/Yushu_Batang_Air...
# 64136                                                NaN
# 64137   https://en.wikipedia.org/wiki/Mudanjiang_Airport
# 64138  https://en.wikipedia.org/wiki/Mohe_Gulian_Airport
# 64139      https://en.wikipedia.org/wiki/Qiqihar_Airport
# 64140  https://en.wikipedia.org/wiki/Songyuan_Chaganh...
# 64141                                                NaN
# 64142  https://en.wikipedia.org/wiki/Dalian_Zhoushuiz...
# 64143  https://en.wikipedia.org/wiki/Tonghua_Sanyuanp...
# 64144  https://en.wikipedia.org/wiki/Shenyang_Taoxian...
# 64145                                                NaN
# 64146  https://en.wikipedia.org/wiki/Yanji_Chaoyangch...
# 64147  https://en.wikipedia.org/wiki/Yingkou_Lanqi_Ai...
# 64148                                                NaN
# 64150                                                NaN
# 64151                                                NaN
# 64152  http://wikimapia.org/6705190/Satsuma-Iwo-jima-...
#
#                     keywords
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                       00AR
# 5                        NaN
# 6                        NaN
# 7                        NaN
# 8                        NaN
# 10                      00CO
# 11                       NaN
# 13                       NaN
# 14                       NaN
# 17                       NaN
# 18                       NaN
# 19                      00II
# 20                       NaN
# 22                       NaN
# 23                       NaN
# 24                       NaN
# 27                       NaN
# 28                       NaN
# 30                       NaN
# 31                       5K8
# 33                       NaN
# 34                       NaN
# 36                       NaN
# 37                       NaN
# 38                 64D, 00OH
# 40                       NaN
# 43                       NaN
# ...                      ...
# 64122                    NaN
# 64123                    NaN
# 64124                    NaN
# 64125                    NaN
# 64126                    根河市
# 64127                    NaN
# 64128                    NaN
# 64129                    NaN
# 64130                    NaN
# 64131                    NaN
# 64132                    NaN
# 64133    Xiaolingzi Air Base
# 64134     Yichun Shi Airport
# 64135                    NaN
# 64136                    NaN
# 64137             Mudanjiang
# 64138                    NaN
# 64139                    NaN
# 64140                    NaN
# 64141                    NaN
# 64142        Dalian Air Base
# 64143  Tonghua Liuhe Airport
# 64144                    NaN
# 64145                    NaN
# 64146                    NaN
# 64147                    NaN
# 64148                    NaN
# 64150                    NaN
# 64151                    NaN
# 64152   SATSUMA,IWOJIMA,RJX7
#
# [49096 rows x 18 columns]

# %%
airports.groupby(['iso_country', 'type']).size()  #pandas

#select iso_country, type, count(*) from airports group by iso_country, type 
#order by iso_country, type
# Out:
# iso_country  type
# AD           closed              1
#              heliport            2
# AE           closed              2
#              heliport           78
#              large_airport       4
#              medium_airport      7
#              seaplane_base       4
#              small_airport      18
# AF           closed              3
#              heliport            9
#              medium_airport      9
#              small_airport      53
# AG           closed              1
#              medium_airport      1
#              small_airport       2
# AI           closed              1
#              medium_airport      1
# AL           closed              5
#              heliport            4
#              large_airport       1
#              medium_airport      2
#              small_airport       2
# AM           closed              4
#              heliport            1
#              large_airport       1
#              medium_airport      2
#              small_airport       8
# AO           closed             10
#              heliport            1
#              large_airport       1
#                               ...
# VN           small_airport      15
# VU           closed              5
#              large_airport       1
#              medium_airport      3
#              small_airport      27
# WF           medium_airport      2
# WS           closed              2
#              medium_airport      1
#              small_airport       2
# XK           closed              3
#              heliport            2
#              large_airport       1
#              medium_airport      1
# YE           medium_airport     11
#              small_airport      18
# YT           medium_airport      1
# ZA           closed             20
#              heliport           28
#              large_airport       4
#              medium_airport     56
#              small_airport     443
# ZM           closed              1
#              large_airport       1
#              medium_airport      7
#              small_airport      94
# ZW           closed              2
#              large_airport       1
#              medium_airport      8
#              small_airport     131
# ZZ           heliport            1
# Length: 913, dtype: int64

# %%
airports.groupby(['iso_country', 'type']).size()
# select iso_country, type, count(*) from airports group by iso_country, type 
# order by iso_country, type
# Out:
# iso_country  type
# AD           closed              1
#              heliport            2
# AE           closed              2
#              heliport           78
#              large_airport       4
#              medium_airport      7
#              seaplane_base       4
#              small_airport      18
# AF           closed              3
#              heliport            9
#              medium_airport      9
#              small_airport      53
# AG           closed              1
#              medium_airport      1
#              small_airport       2
# AI           closed              1
#              medium_airport      1
# AL           closed              5
#              heliport            4
#              large_airport       1
#              medium_airport      2
#              small_airport       2
# AM           closed              4
#              heliport            1
#              large_airport       1
#              medium_airport      2
#              small_airport       8
# AO           closed             10
#              heliport            1
#              large_airport       1
#                               ...
# VN           small_airport      15
# VU           closed              5
#              large_airport       1
#              medium_airport      3
#              small_airport      27
# WF           medium_airport      2
# WS           closed              2
#              medium_airport      1
#              small_airport       2
# XK           closed              3
#              heliport            2
#              large_airport       1
#              medium_airport      1
# YE           medium_airport     11
#              small_airport      18
# YT           medium_airport      1
# ZA           closed             20
#              heliport           28
#              large_airport       4
#              medium_airport     56
#              small_airport     443
# ZM           closed              1
#              large_airport       1
#              medium_airport      7
#              small_airport      94
# ZW           closed              2
#              large_airport       1
#              medium_airport      8
#              small_airport     131
# ZZ           heliport            1
# Length: 913, dtype: int64
